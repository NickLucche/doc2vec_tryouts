# %% [markdown]
# # Get training corpus from Wikipedia
# first approach will be downloading a lot of documents summaries,
# which are the first rows of a Wikipedia page.
# Without any parallelization it should take more than a hour

# %%
import wikipedia
import json
import random
import time
import datetime

# the idea is to retrieve a lot of documents from wikipedia, in order to train a Doc2Vec model 
# the documents will then be dumped to disk in json format
filename = 'wikipedia_trainig_corpus.json'
training_corpus_size = 10000
docs_to_avoid = []
wikipedia.set_lang('it')
wikipedia.set_rate_limiting(True) # w/ default timeout value
docs = []
batch_size = 50
for i in range(training_corpus_size//batch_size):
    # get a random page title
    titles = wikipedia.random(pages=batch_size) # Consider making multiple requests!
    for title in titles:
        if title in docs_to_avoid:
            continue # these docs will only result in Exceptions
        summary = ''
        try:
            summary = wikipedia.summary(title)
        except wikipedia.exceptions.DisambiguationError as e:
            try:
                # disambiguation page showed up, fetch a random one (among the first articles)
                index = random.randint(0, (len(e.options)-1)//2)
                summary = wikipedia.summary(e.options[index])
            except wikipedia.exceptions.DisambiguationError as e:
                # sometimes e.options doesn't really help..
                # we'll rule out this word
                docs_to_avoid.append(title)
                print("Bad exception occurred")
                continue
            except:
                # another weird error from wikipedia
                print("Weird error, like page id not found")
                continue
        except wikipedia.exceptions.WikipediaException as we:
            # something wrong (probably can't connect)
            print("Something went wrong..", we)
            continue
        dictionary = {'title':title, 'abstract': summary}
        docs.append(dictionary)
    print("Still working! {0} pages collected.{1}".format((i+1)*batch_size, datetime.datetime.now().time()))
    if (i%(10000//batch_size))==0:
        print("10000 pages milestone.")
        print("Docs to avoid length: ", len(docs_to_avoid))
print("Pages retrieved!")
with open(filename, 'w') as out:
    json.dump(docs, out, indent=4, ensure_ascii=False)
print('File saved!')
print(len(docs))
# Out:
# /home/nick/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/nick/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# Bad exception occurred
# Still working! 50 pages collected.20:05:33.893893
# 10000 pages milestone.
# Docs to avoid length:  1
# Still working! 100 pages collected.20:06:46.505716
# Bad exception occurred
# Bad exception occurred
# Still working! 150 pages collected.20:08:06.288586
# Bad exception occurred
# Bad exception occurred
# Still working! 200 pages collected.20:09:24.912642
# Bad exception occurred
# Still working! 250 pages collected.20:10:36.075001
# Still working! 300 pages collected.20:11:50.331549
# Still working! 350 pages collected.20:13:06.946874
# Bad exception occurred
# Still working! 400 pages collected.20:14:23.982207
# Bad exception occurred
# Bad exception occurred
# Still working! 450 pages collected.20:15:40.889977
# Bad exception occurred
# Bad exception occurred
# Still working! 500 pages collected.20:17:01.541116
# Bad exception occurred
# Bad exception occurred
# Still working! 550 pages collected.20:18:26.515658
# Still working! 600 pages collected.20:19:46.159884
# Still working! 650 pages collected.20:21:03.256767
# Still working! 700 pages collected.20:22:21.340797
# Still working! 750 pages collected.20:23:38.010412
# Bad exception occurred
# Bad exception occurred
# Still working! 800 pages collected.20:24:56.567774
# Bad exception occurred
# Still working! 850 pages collected.20:26:18.912416
# Something went wrong.. Page id "trois" does not match any pages. Try another id!
# Still working! 900 pages collected.20:27:34.916807
# Bad exception occurred
# Still working! 950 pages collected.20:28:54.255938
# Still working! 1000 pages collected.20:30:09.623614
# Still working! 1050 pages collected.20:31:25.454428
# Bad exception occurred
# Bad exception occurred
# Bad exception occurred
# Still working!
# Bad exception occurred
# Bad exception occurred
# Bad exception occurred
# Still working! 8800 pages collected.23:55:57.070384
# Bad exception occurred
# Still working! 8850 pages collected.23:57:16.597863
# Bad exception occurred
# Still working! 8900 pages collected.23:58:37.366928
# Something went wrong.. Page id "higashi metropolitana di kyoto" does not match any pages. Try another id!
# Bad exception occurred
# Bad exception occurred
# Still working! 8950 pages collected.23:59:53.894598
# Bad exception occurred
# Bad exception occurred
# Still working! 9000 pages collected.00:01:10.828252
# Still working! 9050 pages collected.00:02:29.575073
# Still working! 9100 pages collected.00:03:43.299703
# Bad exception occurred
# Weird error, like page id not found
# Still working! 9150 pages collected.00:05:01.596168
# Bad exception occurred
# Still working! 9200 pages collected.00:06:15.976366
# Still working! 9250 pages collected.00:07:32.272957
# Weird error, like page id not found
# Bad exception occurred
# Still working! 9300 pages collected.00:08:50.092020
# Bad exception occurred
# Still working! 9350 pages collected.00:10:08.588352
# Bad exception occurred
# Still working! 9400 pages collected.00:11:26.055619
# Bad exception occurred
# Bad exception occurred
# Still working! 9450 pages collected.00:12:47.822498
# Still working! 9500 pages collected.00:14:03.652067
# Still working! 9550 pages collected.00:15:17.278336
# Bad exception occurred
# Still working! 9600 pages collected.00:16:35.887431
# Something went wrong.. Page id "paris saint germain football club 2012 2012" does not match any pages. Try another id!
# Bad exception occurred
# Still working! 9650 pages collected.00:17:54.653030
# Still working! 9700 pages collected.00:19:10.198629
# Still working! 9750 pages collected.00:19:28.082627
# Bad exception occurred
# Bad exception occurred
# Still working! 9800 pages collected.00:20:45.598039
# Still working! 9850 pages collected.00:21:59.585557
# Still working! 9900 pages collected.00:23:13.858723
# Something went wrong.. Page id "super lig 2011 2012 pallavolo femminile spagna" does not match any pages. Try another id!
# Still working! 9950 pages collected.00:24:32.884379
# Still working! 10000 pages collected.00:25:50.083418
# Still working! 10050 pages collected.00:27:05.349764
# 10000 pages milestone.
# Docs to avoid length:  187
# Bad exception occurred
# Something went wrong.. Page id "caribes de san sebastián pallavolo maschile 2012 2014" does not match any pages. Try another id!
# Still working! 10100 pages collected.00:28:22.380428
# Still working! 10150 pages collected.00:29:42.623444
# Bad exception occurred
# Still working! 10200 pages collected.00:30:55.395421
# Still working! 10250 pages collected.00:32:16.087786
# Bad exception occurred
# Bad exception occurred
# Still working! 10300 pages collected.00:33:32.460091
# Still working! 10350 pages collected.00:34:49.239635
# Bad exception occurred
# Bad exception occurred
# Still working! 10400 pages collected.00:36:06.676310
# Weird error, like page id not found
# Still working! 10450 pages collected.00:37:23.277294
# Bad exception occurred
# Still working! 10500 pages collected.00:38:39.638619
# Still working! 10550 pages collected.00:39:53.905180
# Bad exception occurred

# %%
wikipedia.set_lang('it')
import random
try:
        summary = wikipedia.summary('Corsa')
except wikipedia.exceptions.DisambiguationError as e:
        # disambiguation page showed up, fetch a random one (among the first articles)
        print(e)
        index = random.randint(0, (len(e.options)-1)//2)
        summary = wikipedia.summary(e.options[5])
print(summary)
# Out:
# /home/nick/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/nick/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# "Corsa" may refer to:
# Corsa
# Corsa
# Corsa
# Corsa
# Corsa
# Wikizionario
#
# Il Wikizionario è un progetto collaborativo, multilingue e gratuito, tramite la Rete, supportato dalla Wikimedia Foundation, per produrre un dizionario online libero e multilingue, con significati, etimologie e pronunce, attraverso l'uso di una piattaforma wiki in maniera del tutto simile a Wikipedia di cui è un compagno lessicale.
