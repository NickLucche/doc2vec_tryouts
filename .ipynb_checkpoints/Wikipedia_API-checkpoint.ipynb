# %%
import sys
# !{sys.executable} -m pip install wikipedia
# Out:
# Collecting wikipedia
#   Downloading https://files.pythonhosted.org/packages/67/35/25e68fbc99e672127cc6fbb14b8ec1ba3dfef035bf1e4c90f78f24a80b7d/wikipedia-1.4.0.tar.gz
# Requirement already satisfied: beautifulsoup4 in /home/nick/anaconda3/lib/python3.6/site-packages (from wikipedia) (4.6.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in /home/nick/anaconda3/lib/python3.6/site-packages (from wikipedia) (2.18.4)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/nick/anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /home/nick/anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /home/nick/anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nick/anaconda3/lib/python3.6/site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2018.4.16)
# Building wheels for collected packages: wikipedia
#   Running setup.py bdist_wheel for wikipedia ... done
#   Stored in directory: /home/nick/.cache/pip/wheels/87/2a/18/4e471fd96d12114d16fe4a446d00c3b38fb9efcb744bd31f4a
# Successfully built wikipedia
# distributed 1.21.8 requires msgpack, which is not installed.
# Installing collected packages: wikipedia
# Successfully installed wikipedia-1.4.0
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
print(wikipedia.random(pages = 1))
try:
    print(wikipedia.summary("Real Madrid", sentences = 3))
except wikipedia.exceptions.DisambiguationError as e:
    wikipedia.summary(e.options[0])
# Out:
# Downside Up
# Il Real Madrid Club de Fútbol, più semplicemente noto come Real Madrid, è una società polisportiva spagnola la cui fama mondiale è determinata soprattutto dalla sua sezione calcistica.
# Fondato a Madrid il 6 marzo 1902, con la denominazione ufficiale di Madrid Club de Fútbol, si vide assegnare il titolo di Real nel 1920, dal re Alfonso XIII di Spagna, insieme all’ormai famigerata corona a decorarne e arricchirne lo stemma.
# La squadra di calcio milita in Primera División fin dalla prima edizione del torneo nella stagione 1928-29 e può vantare il palmarès più prestigioso al mondo, relativamente ai campionati più competitivi.

# %%
import wikipedia

#print(wikipedia.search("Barack", results=1))
wikipedia.suggest("Mercury (element)") #doesn't do much
try:
    print(wikipedia.search("Mercury", results = 1))
    print(wikipedia.summary("Mercury", sentences = 6))
except wikipedia.exceptions.DisambiguationError as e:
    # if dimbaguations page shows up, take the first document
    print(wikipedia.summary(e.options[0], sentences=6))
    
# get wikipedia page categorie's
try:
    ny = wikipedia.page('New York')
except wikipedia.exceptions.DisambiguationError as e:
    ny = wikipedia.page(e.options[0])
print(ny.content[:20])
#print(ny.categories)
# Out:
# ['Freddie Mercury']
# Freddie Mercury, pseudonimo di Farrokh Bulsara (Zanzibar, 5 settembre 1946 – Londra, 24 novembre 1991), è stato un cantautore, musicista e compositore britannico di origini parsi.
# Ricordato per il talento vocale e la sua esuberante personalità sul palco, è considerato uno dei più celebri e influenti artisti nella storia del rock: universalmente riconosciuto come uno dei migliori frontman nella storia della musica, nel 2008 la rivista statunitense Rolling Stone lo classificò 18º nella classifica dei migliori cento cantanti di tutti i tempi, mentre l'anno successivo Classic Rock lo classificò al primo posto tra le voci rock.Fu fondatore nel 1970 dei Queen, gruppo rock britannico di cui fece parte fino alla morte. Per i Queen fu autore della maggior parte dei brani, tra i quali si annoverano successi come Bohemian Rhapsody, Crazy Little Thing Called Love, Don't Stop Me Now, It's a Hard Life, Killer Queen, Love of My Life, Play the Game, Somebody to Love e We Are the Champions. Oltre all'attività con i Queen, negli anni ottanta intraprese la carriera solista con la pubblicazione di due album, Mr. Bad Guy (1985) e Barcelona (1988), quest'ultimo frutto della collaborazione con la cantante soprano spagnola Montserrat Caballé, il cui singolo omonimo divenne l'inno ufficiale dei Giochi della XXV Olimpiade svoltisi a Barcellona.Ammalatosi di AIDS, sviluppò a causa di ciò una grave broncopolmonite che lo portò alla morte, sopravvenuta il giorno seguente alla pubblica dichiarazione del suo grave stato di salute.
# In suo onore, il 20 aprile 1992 fu organizzato il Freddie Mercury Tribute Concert, al quale parteciparono molti artisti musicali internazionali; i proventi dell'evento furono utilizzati per fondare The Mercury Phoenix Trust, organizzazione impegnata nella lotta all'HIV, il virus alla base della sindrome da immunodeficienza acquisita.
# New York (AFI: /njuˈ

# %%
# !{sys.executable} -m pip install wikipedia-api
# Out:
# Collecting wikipedia-api
#   Downloading https://files.pythonhosted.org/packages/60/f1/8df8ce6885d1aec74a3c6169077086cd00868d5866c5a2225644a05037bf/Wikipedia-API-0.3.7.tar.gz
# Requirement already satisfied: requests in /home/nick/anaconda3/lib/python3.6/site-packages (from wikipedia-api) (2.18.4)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/nick/anaconda3/lib/python3.6/site-packages (from requests->wikipedia-api) (3.0.4)
# Requirement already satisfied: idna<2.7,>=2.5 in /home/nick/anaconda3/lib/python3.6/site-packages (from requests->wikipedia-api) (2.6)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /home/nick/anaconda3/lib/python3.6/site-packages (from requests->wikipedia-api) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in /home/nick/anaconda3/lib/python3.6/site-packages (from requests->wikipedia-api) (2018.4.16)
# Building wheels for collected packages: wikipedia-api
#   Running setup.py bdist_wheel for wikipedia-api ... done
#   Stored in directory: /home/nick/.cache/pip/wheels/cd/72/d5/465cd0913fcb1470633326011d9b758bc1c592ce68b3bb7a98
# Successfully built wikipedia-api
# distributed 1.21.8 requires msgpack, which is not installed.
# Installing collected packages: wikipedia-api
# Successfully installed wikipedia-api-0.3.7
# You are using pip version 10.0.1, however version 18.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
## for categories we need another API
import wikipediaapi
wiki_wiki = wikipediaapi.Wikipedia('en')
## categories
def print_categorymembers(categorymembers, level=0, max_level=2):
        for c in categorymembers.values():
            print("%s: %s (ns: %d)" % ("*" * (level + 1), c.title, c.ns))
            if c.ns == wikipediaapi.Namespace.CATEGORY and level <= max_level:
                print_categorymembers(c.categorymembers, level + 1)


cat = wiki_wiki.page("Category:Physics")
print("Category members: Category:Physics")
#print_categorymembers(cat.categorymembers)
# Out:
# Category members: Category:Physics
# *: Physics (ns: 0)
# *: Outline of physics (ns: 0)
# *: Glossary of classical physics (ns: 0)
# *: Portal:Physics (ns: 100)
# *: Action-angle coordinates (ns: 0)
# *: Aerometer (ns: 0)
# *: Bayesian model of computational anatomy (ns: 0)
# *: Group actions in computational anatomy (ns: 0)
# *: Blasius–Chaplygin formula (ns: 0)
# *: Cabbeling (ns: 0)
# *: Camelback potential (ns: 0)
# *: CCPForge (ns: 0)
# *: Center of percussion (ns: 0)
# *: Computational anatomy (ns: 0)
# *: Conformon (ns: 0)
# *: Diffeomorphometry (ns: 0)
# *: Diffraction-limited storage ring (ns: 0)
# *: Diffuse field acoustic testing (ns: 0)
# *: Dirac membrane (ns: 0)
# *: Dispersive medium (ns: 0)
# *: Droplet vaporization (ns: 0)
# *: Electron heat capacity (ns: 0)
# *: Elitzur–Vaidman bomb tester (ns: 0)
# *: Energy well (ns: 0)
# *: Farris effect (rheology) (ns: 0)
# *: Front (physics) (ns: 0)
# *: Gravitationally-interacting massive particles (ns: 0)
# *: Harmonic (ns: 0)
# *: Homeokinetics (ns: 0)
# *: Hopkinson effect (ns: 0)
# *: Infinite derivative gravity (ns: 0)
# *: Interface (matter) (ns: 0)
# *: Jahn–Teller effect (ns: 0)
# *: Landolt–Börnstein (ns: 0)
# *: Large deformation diffeomorphic metric mapping (ns: 0)
# *: Physical law (ns: 0)
# *: Many-body theory (ns: 0)
# *: Microfluidic cell culture (ns: 0)
# *: Nonlinear frictiophoresis (ns: 0)
# *: Normal contact stiffness (ns: 0)
# *: Northwest Nuclear Consortium (ns: 0)
# *: Orders of magnitude (density) (ns: 0)
# *: Parallel force system (ns: 0)
# *: Phase stretch transform (ns: 0)
# *: Plexciton (ns: 0)
# *: Pseudo Jahn–Teller effect (ns: 0)
# *: RAON (ns: 0)
# *: Resistive plate chamber (ns: 0)
# *: Riemannian metric and Lie bracket in computational anatomy (ns: 0)
# *: Rogue wave (ns: 0)
# *: Self-propulsion (ns: 0)
# *: Silicon nanowire (ns: 0)
# *: Solid light (ns: 0)
# *: Solid-state physics (ns: 0)
# *: Statistical mechanics (ns: 0)
# *: Stochastic thermodynamics (ns: 0)
# *: Straw tracker (ns: 0)
# *: Total position spread (ns: 0)
# *: Transparent wood composites (ns: 0)
# *: Verwey transition (ns: 0)
# *: Weak gravity conjecture (ns: 0)
# *: Wigner rotation (ns: 0)
# *: Williams spray equation (ns: 0)
# *: Ned Wingreen (ns: 0)
# *: Zero-point energy (ns: 0)
# *: Category:Concepts in physics (ns: 14)
# **: 4D vector (ns: 0)
# **: Active and passive transformation (ns: 0)
# **: Ansatz (ns: 0)
# **: Araki–Sucher correction (ns: 0)
# **: Arrow of time (ns: 0)
# **: Asymptotic safety in quantum gravity (ns: 0)
# **: Bell's theorem (ns: 0)
# **: Boltzmann's entropy formula (ns: 0)
# **: Born reciprocity (ns: 0)
# **: Bose–Einstein statistics (ns: 0)
# **: Brownian ratchet (ns: 0)
# **: Canonical transformation (ns: 0)
# **: Capacitance (ns: 0)
# **: Capstan equation (ns: 0)
# **: Cauchy momentum equation (ns: 0)
# **: Causality (ns: 0)
# **: Causality (physics) (ns: 0)
# **: Cherenkov radiation (ns: 0)
# **: Classical fluid (ns: 0)
# **: Classical limit (ns: 0)
# **: Classical mechanics (ns: 0)
# **: Clausius–Mossotti relation (ns: 0)
# **: Clockwise (ns: 0)
# **: Closed system (ns: 0)
# **: Coherence (physics) (ns: 0)
# **: Coherent turbulent structure (ns: 0)
# **: Commutative property (ns: 0)
# **: Composite Higgs models (ns: 0)
# **: Time crystal (ns: 0)
# **: Conservation law (ns: 0)
# **: Contracted Bianchi identities (ns: 0)
# **: Convection (ns: 0)
# **: Cooper pair (ns: 0)
# **: Copenhagen interpretation (ns: 0)
# **: Coulomb gap (ns: 0)
# **: Covariance group (ns: 0)
# **: Covariance principle (ns: 0)
# **: Covariant formulation of classical electromagnetism (ns: 0)
# **: Cross section (physics) (ns: 0)
# **: Current density (ns: 0)
# **: Darwin Lagrangian (ns: 0)
# **: Degenerate semiconductor (ns: 0)
# **: Degrees of freedom (physics and chemistry) (ns: 0)
# **: Density of states (ns: 0)
# **: Diffraction (ns: 0)
# **: Diffraction formalism (ns: 0)
# **: Dimension (ns: 0)
# **: Discrete spectrum (ns: 0)
# **: Dispersion relation (ns: 0)
# **: Einstein's thought experiments (ns: 0)
# **: Elastance (ns: 0)
# **: Electromagnet (ns: 0)
# **: Electromagnetic induction (ns: 0)
# **: Electron equivalent (ns: 0)
# **: Electronic entropy (ns: 0)
# **: Electrostatics (ns: 0)
# **: Elementary particle (ns: 0)
# **: Emission spectrum (ns: 0)
# **: Empty lattice approximation (ns: 0)
# **: Enthalpy (ns: 0)
# **: Entropy (ns: 0)
# **: Configuration entropy (ns: 0)
# **: EPR paradox (ns: 0)
# **: Equation of state (ns: 0)
# **: Equipartition theorem (ns: 0)
# **: Equivalence principle (ns: 0)
# **: Equivalence principle (geometric) (ns: 0)
# **: Ergodic hypothesis (ns: 0)
# **: Euclidean vector (ns: 0)
# **: Euler equations (fluid dynamics) (ns: 0)
# **: Euler's laws of motion (ns: 0)
# **: Ewald–Oseen extinction theorem (ns: 0)
# **: Fermi gas (ns: 0)
# **: Fermi's golden rule (ns: 0)
# **: Fermion (ns: 0)
# **: Feynman diagram (ns: 0)
# **: Field (physics) (ns: 0)
# **: Field effect (semiconductor) (ns: 0)
# **: Fine-structure constant (ns: 0)
# **: First law of thermodynamics (ns: 0)
# **: First observation of gravitational waves (ns: 0)
# **: Flavour (particle physics) (ns: 0)
# **: Flotation of flexible objects (ns: 0)
# **: Four-vector (ns: 0)
# **: Fractional quantum mechanics (ns: 0)
# **: Fractional Schrödinger equation (ns: 0)
# **: Frame-dragging (ns: 0)
# **: Free electron model (ns: 0)
# **: Free neutron decay (ns: 0)
# **: Free particle (ns: 0)
# **: Frustrated triangular lattice (ns: 0)
# **: Introduction to gauge theory (ns: 0)
# **: Generalized Lagrangian mean (ns: 0)
# **: Gibbs free energy (ns: 0)
# **: Ginzburg criterion (ns: 0)
# **: Global mode (ns: 0)
# **: Gravitational singularity (ns: 0)
# **: Green's function (ns: 0)
# **: Green's function number (ns: 0)
# **: Group velocity dispersion (ns: 0)
# **: H-theorem (ns: 0)
# **: Heat (ns: 0)
# **: Heat engine (ns: 0)
# **: Heisenberg cut (ns: 0)
# **: Helmholtz free energy (ns: 0)
# **: Entropic uncertainty (ns: 0)
# **: Homogeneity (physics) (ns: 0)
# **: Hydrodynamic quantum analogs (ns: 0)
# **: Hydrogen atom (ns: 0)
# **: Impulse (physics) (ns: 0)
# **: Instability (ns: 0)
# **: Integral length scale (ns: 0)
# **: Internal energy (ns: 0)
# **: Intrinsic parity (ns: 0)
# **: Invariant (physics) (ns: 0)
# **: Invariant mass (ns: 0)
# **: Ionic conductivity (solid state) (ns: 0)
# **: Kinetic scheme (ns: 0)
# **: Kinetic theory of gases (ns: 0)
# **: Komar superpotential (ns: 0)
# **: Koopman–von Neumann classical mechanics (ns: 0)
# **: Lagrangian mechanics (ns: 0)
# **: Lamb shift (ns: 0)
# **: Legendre transformation (ns: 0)
# **: Leggett inequality (ns: 0)
# **: Length measurement (ns: 0)
# **: Lepton (ns: 0)
# **: Linear response function (ns: 0)
# **: Linear system (ns: 0)
# **: Linearity (ns: 0)
# **: Long-slit spectroscopy (ns: 0)
# **: Lorentz force (ns: 0)
# **: Lorentz scalar (ns: 0)
# **: Lorenz gauge condition (ns: 0)
# **: Macroscopic scale (ns: 0)
# **: Magnetic braking (ns: 0)
# **: Majorana fermion (ns: 0)
# **: Mass versus weight (ns: 0)
# **: Mass-to-charge ratio (ns: 0)
# **: Master equation (ns: 0)
# **: Introduction to the mathematics of general relativity (ns: 0)
# **: Maxwell–Boltzmann statistics (ns: 0)
# **: Maxwell's demon (ns: 0)
# **: List of textbooks in electromagnetism (ns: 0)
# **: Matrix representation of Maxwell's equations (ns: 0)
# **: Maxwell's equations in curved spacetime (ns: 0)
# **: Mean field theory (ns: 0)
# **: Mean inter-particle distance (ns: 0)
# **: Measure (physics) (ns: 0)
# **: Mechanics (ns: 0)
# **: Melting point (ns: 0)
# **: Meter water equivalent (ns: 0)
# **: Metric tensor (ns: 0)
# **: Microscopic scale (ns: 0)
# **: Minkowski space (ns: 0)
# **: Motion (physics) (ns: 0)
# **: Navier–Stokes equations (ns: 0)
# **: Negative frequency (ns: 0)
# **: Negative refraction (ns: 0)
# **: Newton's law of cooling (ns: 0)
# **: Newton's laws of motion (ns: 0)
# **: Newton's theorem of revolving orbits (ns: 0)
# **: Newtonian dynamics (ns: 0)
# **: Newtonian motivations for general relativity (ns: 0)
# **: Node (physics) (ns: 0)
# **: Noether's theorem (ns: 0)
# **: Non-contact force (ns: 0)
# **: Non-equilibrium thermodynamics (ns: 0)
# **: Nonlinear system (ns: 0)
# **: Nuclear fusion (ns: 0)
# **: Nuclear physics (ns: 0)
# **: Nuclear reaction (ns: 0)
# **: Observer (physics) (ns: 0)
# **: Observer (quantum physics) (ns: 0)
# **: Observer effect (physics) (ns: 0)
# **: One-electron universe (ns: 0)
# **: Onsager reciprocal relations (ns: 0)
# **: Optogalvanic effect (ns: 0)
# **: Palatini identity (ns: 0)
# **: Paramagnetism (ns: 0)
# **: Parity (physics) (ns: 0)
# **: Partial differential equation (ns: 0)
# **: Partition function (statistical mechanics) (ns: 0)
# **: Path integral formulation (ns: 0)
# **: Pauli exclusion principle (ns: 0)
# **: Permittivity (ns: 0)
# **: Perturbation theory (ns: 0)
# **: Phase (matter) (ns: 0)
# **: Phase space (ns: 0)
# **: Phase transition (ns: 0)
# **: Photon polarization (ns: 0)
# **: Physical body (ns: 0)
# **: Physical information (ns: 0)
# **: Physical theories modified by general relativity (ns: 0)
# **: Physics applications of asymptotically safe gravity (ns: 0)
# **: Plasma (physics) (ns: 0)
# **: Point particle (ns: 0)
# **: Poisson bracket (ns: 0)
# **: Polynomial Wigner–Ville distribution (ns: 0)
# **: Potential gradient (ns: 0)
# **: Potentiometric surface (ns: 0)
# **: Power (physics) (ns: 0)
# **: Pressure (ns: 0)
# **: Principle of covariance (ns: 0)
# **: Principle of least action (ns: 0)
# **: Probability amplitude (ns: 0)
# **: Probability density function (ns: 0)
# **: Probability of occupation (ns: 0)
# **: Pulse (physics) (ns: 0)
# **: QED vacuum (ns: 0)
# **: Quantization (physics) (ns: 0)
# **: Quantum chromodynamics (ns: 0)
# **: Quantum chromodynamics binding energy (ns: 0)
# **: Quantum electrodynamics (ns: 0)
# **: Quantum field theory (ns: 0)
# **: User:Yinweichen/sandbox (ns: 2)
# **: Quantum hadrodynamics (ns: 0)
# **: Quantum mechanics (ns: 0)
# **: Quantum non-equilibrium (ns: 0)
# **: Quantum number (ns: 0)
# **: Quantum potential (ns: 0)
# **: Quantum pseudo-telepathy (ns: 0)
# **: Quantum triviality (ns: 0)
# **: The Quantum Vacuum: An Introduction to Quantum Electrodynamics (ns: 0)
# **: Quasiparticle (ns: 0)
# **: Radiation (ns: 0)
# **: Reflection (physics) (ns: 0)
# **: Refraction (ns: 0)
# **: Regularization (physics) (ns: 0)
# **: Relation between Schrödinger's equation and the path integral formulation of quantum mechanics (ns: 0)
# **: Relational approach to quantum physics (ns: 0)
# **: Relationship between string theory and quantum field theory (ns: 0)
# **: Relative density (ns: 0)
# **: Relative locality (ns: 0)
# **: Relativistic heat conduction (ns: 0)
# **: Relativistic Lagrangian mechanics (ns: 0)
# **: Renormalization (ns: 0)
# **: Rest (physics) (ns: 0)
# **: Rotational partition function (ns: 0)
# **: Saturation velocity (ns: 0)
# **: Scalar (physics) (ns: 0)
# **: Scale of temperature (ns: 0)
# **: Scattering (ns: 0)
# **: Schrödinger's cat (ns: 0)
# **: Second law of thermodynamics (ns: 0)
# **: Self-organization (ns: 0)
# **: Self-oscillation (ns: 0)
# **: Shear stress (ns: 0)
# **: Sommerfeld expansion (ns: 0)
# **: Spacetime (ns: 0)
# **: Spatial dispersion (ns: 0)
# **: Spatial scale (ns: 0)
# **: Special relativity (ns: 0)
# **: Specific gravity (ns: 0)
# **: Specific properties (ns: 0)
# **: Spectrum (ns: 0)
# **: Speed of light (ns: 0)
# **: Spontaneous emission (ns: 0)
# **: Standard gravity (ns: 0)
# **: Standard Model (ns: 0)
# **: State space (physics) (ns: 0)
# **: Statistical ensemble (mathematical physics) (ns: 0)
# **: Statistical mechanics (ns: 0)
# **: Stimulated emission (ns: 0)
# **: Stochastic thermodynamics (ns: 0)
# **: Strangeness (ns: 0)
# **: String theory (ns: 0)
# **: Strong interaction (ns: 0)
# **: Super Bloch oscillations (ns: 0)
# **: Superconductivity (ns: 0)
# **: Supercooling (ns: 0)
# **: Superfluid helium-4 (ns: 0)
# **: Superfluidity (ns: 0)
# **: Superposition principle (ns: 0)
# **: Supersymmetric theory of stochastic dynamics (ns: 0)
# **: Supersymmetry (ns: 0)
# **: Surface stress (ns: 0)
# **: Symmetry (physics) (ns: 0)
# **: Physical system (ns: 0)
# **: System size expansion (ns: 0)
# **: Sznajd model (ns: 0)
# **: Temperature (ns: 0)
# **: Tensor (ns: 0)
# **: Ternary fission (ns: 0)
# **: Theoretical motivation for general relativity (ns: 0)
# **: Thermal conduction (ns: 0)
# **: Thermal conductivity (ns: 0)
# **: Thermal equilibrium (ns: 0)
# **: Thermodynamic limit (ns: 0)
# **: Thermodynamics (ns: 0)
# **: Thermomass theory (ns: 0)
# **: Thought experiment (ns: 0)
# **: Three-body problem (ns: 0)
# **: Time (ns: 0)
# **: Time dilation (ns: 0)
# **: Time translation symmetry (ns: 0)
# **: Tipping point (physics) (ns: 0)
# **: Transactional interpretation (ns: 0)
# **: Turbulence (ns: 0)
# **: Two-body problem (ns: 0)
# **: Vacuum (ns: 0)
# **: Variable structure system (ns: 0)
# **: Vasiliev equations (ns: 0)
# **: Vector potential (ns: 0)
# **: Vector space (ns: 0)
# **: Versor (physics) (ns: 0)
# **: Virial theorem (ns: 0)
# **: Virtual particle (ns: 0)
# **: Viscous stress tensor (ns: 0)
# **: Volume (thermodynamics) (ns: 0)
# **: Wave equation (ns: 0)
# **: Wave function collapse (ns: 0)
# **: Wavenumber (ns: 0)
# **: Weak interaction (ns: 0)
# **: Wheelbase (ns: 0)
# **: Wigner quasiprobability distribution (ns: 0)
# **: Wigner–Weyl transform (ns: 0)
# **: Work function (ns: 0)
# **: World tube (ns: 0)
# **: Yang–Mills theory (ns: 0)
# **: Zero-point energy (ns: 0)
# **: Category:Mechanics (ns: 14)
# ***: Mechanics (ns: 0)
# ***: Acoustic lubrication (ns: 0)
# ***: Anchor Force Equation (proof) (ns: 0)
# ***: Applied mechanics (ns: 0)
# ***: List of second moments of area (ns: 0)
# ***: Atwood machine (ns: 0)
# ***: Banked turn (ns: 0)
# ***: Belt friction (ns: 0)
# ***: Body moment (ns: 0)
# ***: Brachistochrone curve (ns: 0)
# ***: Buckling (ns: 0)
# ***: Johann Wilhelm Gottlob Buzengeiger (ns: 0)
# ***: Cam and groove (ns: 0)
# ***: Carroll's paradox (ns: 0)
# ***: William Cartheuser (ns: 0)
# ***: Causal contact (ns: 0)
# ***: Center of percussion (ns: 0)
# ***: Centrifugal force (ns: 0)
# ***: Centripetal force (ns: 0)
# ***: List of centroids (ns: 0)
# ***: Chain drive (ns: 0)
# ***: Chaplygin sleigh (ns: 0)
# ***: Christensen failure criterion (ns: 0)
# ***: Circle-throw vibrating machine (ns: 0)
# ***: Coefficient of restitution (ns: 0)
# ***: Collision (ns: 0)
# ***: Collision course (ns: 0)
# ***: Collision response (ns: 0)
# ***: Comptes Rendus Mécanique (ns: 0)
# ***: Computational aeroacoustics (ns: 0)
# ***: Computational mechanics (ns: 0)
# ***: Conjugate beam method (ns: 0)
# ***: Contact dynamics (ns: 0)
# ***: Couple (mechanics) (ns: 0)
# ***: Cremona diagram (ns: 0)
# ***: Cyclic stress (ns: 0)
# ***: Cylinder stress (ns: 0)
# ***: DBrn (ns: 0)
# ***: Decompression (physics) (ns: 0)
# ***: Degrees of freedom (mechanics) (ns: 0)
# ***: Diaphragm (mechanical device) (ns: 0)
# ***: Differential pulley (ns: 0)
# ***: Directional stability (ns: 0)
# ***: Drucker stability (ns: 0)
# ***: Duhamel's integral (ns: 0)
# ***: Dynamic balance (ns: 0)
# ***: Effective potential (ns: 0)
# ***: Elastic instability (ns: 0)
# ***: Electro-mechanical modeling (ns: 0)
# ***: Electromechanics (ns: 0)
# ***: Engine power (ns: 0)
# ***: Euler's critical load (ns: 0)
# ***: Euler's laws of motion (ns: 0)
# ***: Eversharp (ns: 0)
# ***: Extended finite element method (ns: 0)
# ***: Factor of safety (ns: 0)
# ***: Material failure theory (ns: 0)
# ***: Fall factor (ns: 0)
# ***: Featherstone's algorithm (ns: 0)
# ***: Fit (manufacturing) (ns: 0)
# ***: Four-point flexural test (ns: 0)
# ***: Fracture (ns: 0)
# ***: Free body diagram (ns: 0)
# ***: Friction torque (ns: 0)
# ***: Generalized forces (ns: 0)
# ***: Geomechanics (ns: 0)
# ***: Gravity train (ns: 0)
# ***: Ground reaction force (ns: 0)
# ***: Herpolhode (ns: 0)
# ***: Hoop stress (ns: 0)
# ***: Hosford yield criterion (ns: 0)
# ***: Ideal machine (ns: 0)
# ***: Implosion (mechanical process) (ns: 0)
# ***: Infinitesimal strain theory (ns: 0)
# ***: Innermost stable circular orbit (ns: 0)
# ***: J-integral (ns: 0)
# ***: Johnson's parabolic formula (ns: 0)
# ***: Kelvin–Stokes theorem (ns: 0)
# ***: Kinetic diagram (ns: 0)
# ***: Kirchhoff equations (ns: 0)
# ***: König's theorem (kinetics) (ns: 0)
# ***: Lamé's stress ellipsoid (ns: 0)
# ***: Line of thrust (ns: 0)
# ***: Lumped element model (ns: 0)
# ***: Mass distribution (ns: 0)
# ***: Mathieu transformation (ns: 0)
# ***: Mechanical advantage (ns: 0)
# ***: Mechanical advantage device (ns: 0)
# ***: Mechanical energy (ns: 0)
# ***: Mechanical filter (ns: 0)
# ***: Mechanical traveller (ns: 0)
# ***: Mechanician (ns: 0)
# ***: Mechanics of planar particle motion (ns: 0)
# ***: Membrane analogy (ns: 0)
# ***: Micro-mechanics of failure (ns: 0)
# ***: Mohr's circle (ns: 0)
# ***: List of moments of inertia (ns: 0)
# ***: Momentum (ns: 0)
# ***: Monogenic system (ns: 0)
# ***: Motion (physics) (ns: 0)
# ***: Multi-function structure (ns: 0)
# ***: Multibody system (ns: 0)
# ***: Newton's laws of motion (ns: 0)
# ***: Newtonian dynamics (ns: 0)
# ***: Non-smooth mechanics (ns: 0)
# ***: Normal contact stiffness (ns: 0)
# ***: Pair potential (ns: 0)
# ***: Parallel axis theorem (ns: 0)
# ***: Parallel force system (ns: 0)
# ***: Photoelasticity (ns: 0)
# ***: Photomechanical effect (ns: 0)
# ***: Physical body (ns: 0)
# ***: Physics of skiing (ns: 0)
# ***: Polar moment of inertia (ns: 0)
# ***: Polhode (ns: 0)
# ***: Power-to-weight ratio (ns: 0)
# ***: Precession (mechanical) (ns: 0)
# ***: Pressure drop (ns: 0)
# ***: Projectile motion (ns: 0)
# ***: Pseudo-modal energies (ns: 0)
# ***: Pulley (ns: 0)
# ***: Q factor (ns: 0)
# ***: Radial distribution function (ns: 0)
# ***: Ramberg–Osgood relationship (ns: 0)
# ***: Reactive centrifugal force (ns: 0)
# ***: Reduced mass (ns: 0)
# ***: Resistance distance (mechanics) (ns: 0)
# ***: Rheonomous (ns: 0)
# ***: Right-hand rule (ns: 0)
# ***: Rubber elasticity (ns: 0)
# ***: Sandwich theory (ns: 0)
# ***: Scleronomous (ns: 0)
# ***: Screw theory (ns: 0)
# ***: Self-buckling (ns: 0)
# ***: Shock (mechanics) (ns: 0)
# ***: Shock indicator (ns: 0)
# ***: Six degrees of freedom (ns: 0)
# ***: Slewing (ns: 0)
# ***: Solid mechanics (ns: 0)
# ***: Southwell plot (ns: 0)
# ***: Stall (engine) (ns: 0)
# ***: Stall torque (ns: 0)
# ***: Stiffening (ns: 0)
# ***: Strain energy release rate (ns: 0)
# ***: Stress resultants (ns: 0)
# ***: Structural mechanics (ns: 0)
# ***: Structural rigidity (ns: 0)
# ***: Stuart–Landau equation (ns: 0)
# ***: Tangent stiffness matrix (ns: 0)
# ***: Tautochrone curve (ns: 0)
# ***: Telescoping (mechanics) (ns: 0)
# ***: Tensor derivative (continuum mechanics) (ns: 0)
# ***: Thermal center (ns: 0)
# ***: Three-point flexural test (ns: 0)
# ***: Tooth interior fatigue fracture (ns: 0)
# ***: Torsion (mechanics) (ns: 0)
# ***: Trajectory (ns: 0)
# ***: Truss (ns: 0)
# ***: Tsai–Wu failure criterion (ns: 0)
# ***: Unilateral contact (ns: 0)
# ***: Variable cycle engine (ns: 0)
# ***: Variable-mass system (ns: 0)
# ***: Varignon's theorem (mechanics) (ns: 0)
# ***: Virtual displacement (ns: 0)
# ***: Virtual work (ns: 0)
# ***: Vis viva (ns: 0)
# ***: Wedge (ns: 0)
# ***: Whippletree (mechanism) (ns: 0)
# ***: Work (physics) (ns: 0)
# ***: Yield (engineering) (ns: 0)
# ***: Yield strength anomaly (ns: 0)
# ***: Yoshimura buckling (ns: 0)
# ***: Category:Biomechanics (ns: 14)
# ****: Biomechanics (ns: 0)
# ****: List of biofluid mechanics research groups (ns: 0)
# ****: Aggregate modulus (ns: 0)
# ****: American Society of Biomechanics (ns: 0)
# ****: Aquatic feeding mechanisms (ns: 0)
# ****: Arthropod exoskeleton (ns: 0)
# ****: Balance (ability) (ns: 0)
# ****: Biofluid dynamics (ns: 0)
# ****: Biomechanics of sprint running (ns: 0)
# ****: Bipedal gait cycle (ns: 0)
# ****: Brush border (ns: 0)
# ****: Canadian Society for Biomechanics (ns: 0)
# ****: Center of pressure (terrestrial locomotion) (ns: 0)
# ****: Cometabolism (ns: 0)
# ****: Core (anatomy) (ns: 0)
# ****: Dynamic similarity (Reynolds and Womersley numbers) (ns: 0)
# ****: Ecomechanics (ns: 0)
# ****: Endoskeleton (ns: 0)
# ****: Exoskeleton (ns: 0)
# ****: Flapping counter-torque (ns: 0)
# ****: Force platform (ns: 0)
# ****: Forensic biomechanics (ns: 0)
# ****: Functional movement (ns: 0)
# ****: Functional spinal unit (ns: 0)
# ****: Yuan-Cheng Fung (ns: 0)
# ****: Grasshopper (ns: 0)
# ****: Gray's paradox (ns: 0)
# ****: Ground reaction force (ns: 0)
# ****: Hill's muscle model (ns: 0)
# ****: Hitting mechanics (ns: 0)
# ****: Human skeletal changes due to bipedalism (ns: 0)
# ****: Patria Hume (ns: 0)
# ****: Hydrostatic skeleton (ns: 0)
# ****: I Measure U (ns: 0)
# ****: Iatromathematicians (ns: 0)
# ****: International Foot and Ankle Biomechanics Community (ns: 0)
# ****: International Society of Biomechanics (ns: 0)
# ****: Journal of Applied Biomechanics (ns: 0)
# ****: Key determinants of gait (ns: 0)
# ****: Limits of stability (ns: 0)
# ****: Lines of non-extension (ns: 0)
# ****: Locomotor effects of shoes (ns: 0)
# ****: Mechanics of human sexuality (ns: 0)
# ****: Mechanics of Oscar Pistorius's running blades (ns: 0)
# ****: Mechanome (ns: 0)
# ****: Moens–Korteweg equation (ns: 0)
# ****: Movement assessment (ns: 0)
# ****: Muscular hydrostat (ns: 0)
# ****: Nanobiomechanics (ns: 0)
# ****: Neuro biomechanics (ns: 0)
# ****: Neutral body posture (ns: 0)
# ****: OpenSim (simulation toolkit) (ns: 0)
# ****: Overhand throwing motion (ns: 0)
# ****: Pedobarography (ns: 0)
# ****: Physics of skiing (ns: 0)
# ****: Rotating locomotion in living systems (ns: 0)
# ****: Sauropod neck posture (ns: 0)
# ****: Serape effect (ns: 0)
# ****: Jeffry B. Skiba (ns: 0)
# ****: Soft tissue (ns: 0)
# ****: Sports biomechanics (ns: 0)
# ****: Adrian Thomas (zoologist) (ns: 0)
# ****: Throwing (ns: 0)
# ****: Tinetti test (ns: 0)
# ****: Womersley number (ns: 0)
# ****: Work loop (ns: 0)
# ****: Category:Animal locomotion (ns: 14)
# ***: Category:Classical mechanics (ns: 14)
# ****: Classical mechanics (ns: 0)
# ****: Portal:Classical mechanics (ns: 100)
# ****: Absolute space and time (ns: 0)
# ****: Action-angle coordinates (ns: 0)
# ****: Adiabatic invariant (ns: 0)
# ****: Analytical dynamics (ns: 0)
# ****: Anharmonicity (ns: 0)
# ****: Anti-vibration compound (ns: 0)
# ****: Appell's equation of motion (ns: 0)
# ****: Area density (ns: 0)
# ****: Arnold diffusion (ns: 0)
# ****: Berry connection and curvature (ns: 0)
# ****: Bertrand's theorem (ns: 0)
# ****: Binet equation (ns: 0)
# ****: Bohr–van Leeuwen theorem (ns: 0)
# ****: Bonnet's theorem (ns: 0)
# ****: Bouncing ball (ns: 0)
# ****: Brownian dynamics (ns: 0)
# ****: Bucket argument (ns: 0)
# ****: Capacitor analogy (ns: 0)
# ****: Celestial mechanics (ns: 0)
# ****: Center of mass (ns: 0)
# ****: Center-of-momentum frame (ns: 0)
# ****: Centers of gravity in non-uniform fields (ns: 0)
# ****: Central force (ns: 0)
# ****: Circular motion (ns: 0)
# ****: Classical central-force problem (ns: 0)
# ****: Classical Mechanics (Goldstein book) (ns: 0)
# ****: Classical Mechanics (Kibble and Berkshire book) (ns: 0)
# ****: Coefficient of restitution (ns: 0)
# ****: Complex harmonic motion (ns: 0)
# ****: Configuration space (physics) (ns: 0)
# ****: Conjugate variables (ns: 0)
# ****: Constant of motion (ns: 0)
# ****: Constraint (classical mechanics) (ns: 0)
# ****: Continuum mechanics (ns: 0)
# ****: Materials with memory (ns: 0)
# ****: Coriolis force (ns: 0)
# ****: Cotes's spiral (ns: 0)
# ****: D'Alembert's principle (ns: 0)
# ****: Damping matrix (ns: 0)
# ****: Damping torque (ns: 0)
# ****: Efimov effect (ns: 0)
# ****: Elastic collision (ns: 0)
# ****: Elastic energy (ns: 0)
# ****: Equations of motion (ns: 0)
# ****: Euler's laws of motion (ns: 0)
# ****: Exact solutions of classical central-force problems (ns: 0)
# ****: Falling cat problem (ns: 0)
# ****: Few-body systems (ns: 0)
# ****: Fictitious force (ns: 0)
# ****: First class constraint (ns: 0)
# ****: Force (ns: 0)
# ****: Free body (ns: 0)
# ****: Free motion equation (ns: 0)
# ****: Free particle (ns: 0)
# ****: Frenkel–Kontorova model (ns: 0)
# ****: Friction (ns: 0)
# ****: Fundamental lemma of calculus of variations (ns: 0)
# ****: Galilean invariance (ns: 0)
# ****: Gauss's principle of least constraint (ns: 0)
# ****: Generalized forces (ns: 0)
# ****: Generating function (physics) (ns: 0)
# ****: Geometric mechanics (ns: 0)
# ****: Geometric phase (ns: 0)
# ****: Gravitational two-body problem (ns: 0)
# ****: Hamiltonian field theory (ns: 0)
# ****: Hamiltonian mechanics (ns: 0)
# ****: Hannay angle (ns: 0)
# ****: Helmholtz theorem (classical mechanics) (ns: 0)
# ****: Hertz's principle of least curvature (ns: 0)
# ****: History of classical mechanics (ns: 0)
# ****: Hodograph (ns: 0)
# ****: Holonomic constraints (ns: 0)
# ****: Impact parameter (ns: 0)
# ****: Impulse (physics) (ns: 0)
# ****: Inelastic collision (ns: 0)
# ****: Inertia (ns: 0)
# ****: Inertial frame of reference (ns: 0)
# ****: Initial stability (ns: 0)
# ****: Instant centre of rotation (ns: 0)
# ****: Jerk (physics) (ns: 0)
# ****: Jet force (ns: 0)
# ****: Johnsen–Rahbek effect (ns: 0)
# ****: Kepler problem (ns: 0)
# ****: Kinematic chain (ns: 0)
# ****: Kinematic diagram (ns: 0)
# ****: Kinematics (ns: 0)
# ****: Kirchhoff equations (ns: 0)
# ****: Koopman–von Neumann classical mechanics (ns: 0)
# ****: Lamé's stress ellipsoid (ns: 0)
# ****: Langevin dynamics (ns: 0)
# ****: Laplace–Runge–Lenz vector (ns: 0)
# ****: Lift (force) (ns: 0)
# ****: Linear motion (ns: 0)
# ****: Liouville dynamical system (ns: 0)
# ****: List of equations in classical mechanics (ns: 0)
# ****: Mass flow meter (ns: 0)
# ****: Mass-spring-damper model (ns: 0)
# ****: Mathematical Methods of Classical Mechanics (ns: 0)
# ****: McGehee transformation (ns: 0)
# ****: Mean speed theorem (ns: 0)
# ****: Mechanical similarity (ns: 0)
# ****: Modified Newtonian dynamics (ns: 0)
# ****: Mohr's circle (ns: 0)
# ****: Momentum curtain (ns: 0)
# ****: Monogenic system (ns: 0)
# ****: Motion graphs and derivatives (ns: 0)
# ****: N-body choreography (ns: 0)
# ****: N-body problem (ns: 0)
# ****: Newton second (ns: 0)
# ****: Newton's laws of motion (ns: 0)
# ****: Newton's theorem of revolving orbits (ns: 0)
# ****: Newtonian dynamics (ns: 0)
# ****: Newtonian material (ns: 0)
# ****: Non-autonomous mechanics (ns: 0)
# ****: Non-autonomous system (mathematics) (ns: 0)
# ****: Non-inertial reference frame (ns: 0)
# ****: Nonholonomic system (ns: 0)
# ****: Normal contact stiffness (ns: 0)
# ****: Normal mode (ns: 0)
# ****: Norton's dome (ns: 0)
# ****: Painlevé conjecture (ns: 0)
# ****: Perpendicular axis theorem (ns: 0)
# ****: Physics of firearms (ns: 0)
# ****: Point particle (ns: 0)
# ****: Positive pressure (ns: 0)
# ****: Potential well (ns: 0)
# ****: Primary constraint (ns: 0)
# ****: Rattleback (ns: 0)
# ****: Rayleigh–Lorentz pendulum (ns: 0)
# ****: Reaction (physics) (ns: 0)
# ****: Relative velocity (ns: 0)
# ****: Relativistic system (mathematics) (ns: 0)
# ****: Rheonomous (ns: 0)
# ****: Roberval balance (ns: 0)
# ****: Roll center (ns: 0)
# ****: Roll moment (ns: 0)
# ****: Rolling resistance (ns: 0)
# ****: Rotating reference frame (ns: 0)
# ****: Rotating spheres (ns: 0)
# ****: Rotation (ns: 0)
# ****: Routhian mechanics (ns: 0)
# ****: Scleronomous (ns: 0)
# ****: Secondary Stability (ns: 0)
# ****: Simple harmonic motion (ns: 0)
# ****: Sitnikov problem (ns: 0)
# ****: Sliding (motion) (ns: 0)
# ****: Soft-body dynamics (ns: 0)
# ****: Specific impulse (ns: 0)
# ****: Startup winding (ns: 0)
# ****: Strain rate (ns: 0)
# ****: Stress field (ns: 0)
# ****: Stretch rule (ns: 0)
# ****: Support polygon (ns: 0)
# ****: Surface force (ns: 0)
# ****: System-specific impulse (ns: 0)
# ****: Tennis racket theorem (ns: 0)
# ****: Theory of impetus (ns: 0)
# ****: Three-body problem (ns: 0)
# ****: Tippe top (ns: 0)
# ****: Translational symmetry (ns: 0)
# ****: Two-body problem (ns: 0)
# ****: Udwadia–Kalaba equation (ns: 0)
# ****: Variable-mass system (ns: 0)
# ****: Virtual displacement (ns: 0)
# ****: Category:Celestial mechanics (ns: 14)
# ****: Category:Continuum mechanics (ns: 14)
# ****: Category:Fictitious forces (ns: 14)
# ****: Category:Force (ns: 14)
# ****: Category:Hamiltonian mechanics (ns: 14)
# ****: Category:Kinematics (ns: 14)
# ****: Category:Lagrangian mechanics (ns: 14)
# ****: Category:Rigid bodies mechanics (ns: 14)
# ****: Category:Rotation (ns: 14)
# ****: Category:Classical mechanics stubs (ns: 14)
# ***: Category:Collision (ns: 14)
# ****: Collision (ns: 0)
# ****: Collision avoidance in transportation (ns: 0)
# ****: Deflection (physics) (ns: 0)
# ****: Elastic collision (ns: 0)
# ****: Hypervelocity (ns: 0)
# ****: Impact (mechanics) (ns: 0)
# ****: Inelastic collision (ns: 0)
# ****: Kinetic bombardment (ns: 0)
# ****: Kinetic energy penetrator (ns: 0)
# ****: Satellite collision (ns: 0)
# ****: Comet Shoemaker–Levy 9 (ns: 0)
# ****: Category:Aircraft collisions (ns: 14)
# ****: Category:Bridge disasters caused by collision (ns: 14)
# ****: Category:Impact events (ns: 14)
# ****: Category:Satellite collisions (ns: 14)
# ****: Category:Ship collisions with icebergs (ns: 14)
# ****: Category:Ships sunk in collisions (ns: 14)
# ****: Category:Small-asteroids collision (ns: 14)
# ****: Category:Traffic collisions (ns: 14)
# ****: Category:Train collisions (ns: 14)
# ****: Category:Whale collisions with ships (ns: 14)
# ***: Category:Continuum mechanics (ns: 14)
# ****: Continuum mechanics (ns: 0)
# ****: Arruda–Boyce model (ns: 0)
# ****: Averaged Lagrangian (ns: 0)
# ****: Bending moment (ns: 0)
# ****: Bending of plates (ns: 0)
# ****: Bending stiffness (ns: 0)
# ****: Betti's theorem (ns: 0)
# ****: Bimoment (ns: 0)
# ****: Birch–Murnaghan equation of state (ns: 0)
# ****: Brinkman number (ns: 0)
# ****: Brittleness (ns: 0)
# ****: Bulk temperature (ns: 0)
# ****: Cauchy elastic material (ns: 0)
# ****: Cauchy momentum equation (ns: 0)
# ****: Cauchy number (ns: 0)
# ****: Cauchy stress tensor (ns: 0)
# ****: Clapeyron's theorem (elasticity) (ns: 0)
# ****: Clausius–Duhem inequality (ns: 0)
# ****: Collapsible flow (ns: 0)
# ****: Compatibility (mechanics) (ns: 0)
# ****: Compression (physics) (ns: 0)
# ****: Configurational mechanics (ns: 0)
# ****: Materials with memory (ns: 0)
# ****: Control volume (ns: 0)
# ****: Convective momentum transport (ns: 0)
# ****: Critical resolved shear stress (ns: 0)
# ****: Damage mechanics (ns: 0)
# ****: Deformation (mechanics) (ns: 0)
# ****: Digital image correlation and tracking (ns: 0)
# ****: Dilatant (ns: 0)
# ****: Dislocation creep (ns: 0)
# ****: Displacement field (mechanics) (ns: 0)
# ****: Drucker stability (ns: 0)
# ****: Ductility (ns: 0)
# ****: Dynamic fluid film equations (ns: 0)
# ****: Dynamic substructuring (ns: 0)
# ****: Eckert number (ns: 0)
# ****: Eigenstrain (ns: 0)
# ****: Elastic instability (ns: 0)
# ****: Elastica theory (ns: 0)
# ****: Ensemble (fluid mechanics) (ns: 0)
# ****: Enstrophy (ns: 0)
# ****: Ahmed Cemal Eringen (ns: 0)
# ****: Eshelby's inclusion (ns: 0)
# ****: Extended finite element method (ns: 0)
# ****: FEATool Multiphysics (ns: 0)
# ****: Ferrofluid (ns: 0)
# ****: FIDYST (ns: 0)
# ****: Finite element method (ns: 0)
# ****: Dynamic design analysis method (ns: 0)
# ****: Finite strain theory (ns: 0)
# ****: Flexural strength (ns: 0)
# ****: Flow conditioning (ns: 0)
# ****: Flow plasticity theory (ns: 0)
# ****: Flow process (ns: 0)
# ****: Flow velocity (ns: 0)
# ****: Fluid dynamics (ns: 0)
# ****: Fluid parcel (ns: 0)
# ****: Föppl–von Kármán equations (ns: 0)
# ****: Force lines (ns: 0)
# ****: Generalized Lagrangian mean (ns: 0)
# ****: Gent (hyperelastic model) (ns: 0)
# ****: Halpin–Tsai model (ns: 0)
# ****: Hu Washizu principle (ns: 0)
# ****: Hydrostatic stress (ns: 0)
# ****: Hyperelastic material (ns: 0)
# ****: Hypoelastic material (ns: 0)
# ****: Impulse excitation technique (ns: 0)
# ****: Infinite element method (ns: 0)
# ****: Izod impact strength test (ns: 0)
# ****: JWL equation of state (ns: 0)
# ****: Kirchhoff–Love plate theory (ns: 0)
# ****: Lateral strain (ns: 0)
# ****: Levy–Mises equations (ns: 0)
# ****: Limit load (physics) (ns: 0)
# ****: Loubignac iteration (ns: 0)
# ****: Lumped damage mechanics (ns: 0)
# ****: Gérard Maugin (ns: 0)
# ****: Membrane theory of shells (ns: 0)
# ****: Mesophase (ns: 0)
# ****: Mie–Gruneisen equation of state (ns: 0)
# ****: Mindlin–Reissner plate theory (ns: 0)
# ****: Mooney–Rivlin solid (ns: 0)
# ****: Murnaghan equation of state (ns: 0)
# ****: Neo-Hookean solid (ns: 0)
# ****: Newtonian material (ns: 0)
# ****: Non-Newtonian fluid (ns: 0)
# ****: Normal strain (ns: 0)
# ****: Objective stress rate (ns: 0)
# ****: Ogden (hyperelastic model) (ns: 0)
# ****: Ogden–Roxburgh model (ns: 0)
# ****: OpenFOAM (ns: 0)
# ****: OpenLB (ns: 0)
# ****: Orthotropic material (ns: 0)
# ****: Peridynamics (ns: 0)
# ****: Piola transformation (ns: 0)
# ****: Plane strain compression test (ns: 0)
# ****: Plate theory (ns: 0)
# ****: Polar moment of inertia (ns: 0)
# ****: Polynomial (hyperelastic model) (ns: 0)
# ****: Poromechanics (ns: 0)
# ****: Pure shear (ns: 0)
# ****: Rankine–Hugoniot conditions (ns: 0)
# ****: Ratcheting (ns: 0)
# ****: Representative elementary volume (ns: 0)
# ****: Residual stress (ns: 0)
# ****: Reversibly assembled cellular composite materials (ns: 0)
# ****: Reynolds transport theorem (ns: 0)
# ****: Rheometry (ns: 0)
# ****: Rock mass plasticity (ns: 0)
# ****: Seismic metamaterial (ns: 0)
# ****: Shakedown (continuum mechanics) (ns: 0)
# ****: Shear and moment diagram (ns: 0)
# ****: Shear rate (ns: 0)
# ****: Shear strain (ns: 0)
# ****: Shear stress (ns: 0)
# ****: Shear thinning (ns: 0)
# ****: Shearing (physics) (ns: 0)
# ****: Signorini problem (ns: 0)
# ****: Simple shear (ns: 0)
# ****: Size effect on structural strength (ns: 0)
# ****: Smoothed finite element method (ns: 0)
# ****: Soft tissue (ns: 0)
# ****: Solid mechanics (ns: 0)
# ****: Stiffness (ns: 0)
# ****: Strain energy density function (ns: 0)
# ****: Strain rate tensor (ns: 0)
# ****: Stream function (ns: 0)
# ****: Streamlines, streaklines, and pathlines (ns: 0)
# ****: Stress measures (ns: 0)
# ****: Stress resultants (ns: 0)
# ****: Stress space (ns: 0)
# ****: Structural fracture mechanics (ns: 0)
# ****: Temperature (ns: 0)
# ****: Theorem of corresponding states (ns: 0)
# ****: Theorem of three moments (ns: 0)
# ****: Theory of tides (ns: 0)
# ****: Thermal fluids (ns: 0)
# ****: Thermomagnetic convection (ns: 0)
# ****: Thixotropy (ns: 0)
# ****: Timoshenko beam theory (ns: 0)
# ****: Torsion constant (ns: 0)
# ****: Toughness (ns: 0)
# ****: Trajectory (fluid mechanics) (ns: 0)
# ****: Variational asymptotic method (ns: 0)
# ****: Velocity gradient (ns: 0)
# ****: Velocity potential (ns: 0)
# ****: Vibrating plate (ns: 0)
# ****: Vibration of plates (ns: 0)
# ****: Virial stress (ns: 0)
# ****: Viscoelasticity (ns: 0)
# ****: Viscoplasticity (ns: 0)
# ****: Vorticity (ns: 0)
# ****: Wave action (continuum mechanics) (ns: 0)
# ****: Yeoh (hyperelastic model) (ns: 0)
# ****: Yield surface (ns: 0)
# ****: Category:Acoustical engineers (ns: 14)
# ****: Category:Acoustics (ns: 14)
# ****: Category:Convection (ns: 14)
# ****: Category:Fluid dynamics (ns: 14)
# ****: Category:Fluid mechanics (ns: 14)
# ****: Category:Fracture mechanics (ns: 14)
# ****: Category:Rheology (ns: 14)
# ****: Category:Shock waves (ns: 14)
# ****: Category:Solid mechanics (ns: 14)
# ****: Category:State functions (ns: 14)
# ****: Category:Thermodynamic processes (ns: 14)
# ****: Category:Thermodynamics (ns: 14)
# ****: Category:Transport phenomena (ns: 14)
# ****: Category:Units of flow (ns: 14)
# ***: Category:Dimensionless numbers of mechanics (ns: 14)
# ****: Cohesion number (ns: 0)
# ****: Damping ratio (ns: 0)
# ****: Love number (ns: 0)
# ***: Category:Dynamical systems (ns: 14)
# ****: Dynamical system (ns: 0)
# ****: Combinatorics and dynamical systems (ns: 0)
# ****: List of dynamical systems and differential equations topics (ns: 0)
# ****: Abelian sandpile model (ns: 0)
# ****: Action-angle coordinates (ns: 0)
# ****: Valentin Afraimovich (ns: 0)
# ****: Amplitude death (ns: 0)
# ****: Analytical mechanics (ns: 0)
# ****: Andronov–Pontryagin criterion (ns: 0)
# ****: Anosov diffeomorphism (ns: 0)
# ****: Arithmetic dynamics (ns: 0)
# ****: Arnold diffusion (ns: 0)
# ****: Artin–Mazur zeta function (ns: 0)
# ****: Autonomous system (mathematics) (ns: 0)
# ****: Behavioral modeling (ns: 0)
# ****: Bifurcation memory (ns: 0)
# ****: Hybrid bond graph (ns: 0)
# ****: Bony–Brezis theorem (ns: 0)
# ****: Boolean delay equation (ns: 0)
# ****: Bost–Connes system (ns: 0)
# ****: Bouncing ball (ns: 0)
# ****: Brjuno number (ns: 0)
# ****: Brownian dynamics (ns: 0)
# ****: Causal system (ns: 0)
# ****: Cellular automaton (ns: 0)
# ****: Center manifold (ns: 0)
# ****: Closed geodesic (ns: 0)
# ****: Cobweb plot (ns: 0)
# ****: Cocycle (ns: 0)
# ****: Community matrix (ns: 0)
# ****: Compartmental modelling of dendrites (ns: 0)
# ****: Composition operator (ns: 0)
# ****: Conley–Zehnder theorem (ns: 0)
# ****: Conserved quantity (ns: 0)
# ****: Contact dynamics (ns: 0)
# ****: Convergence group (ns: 0)
# ****: Correlation dimension (ns: 0)
# ****: Correlation sum (ns: 0)
# ****: Crisis (dynamical systems) (ns: 0)
# ****: D'Alembert's principle (ns: 0)
# ****: De Bruijn graph (ns: 0)
# ****: Denjoy's theorem on rotation number (ns: 0)
# ****: Deterministic system (ns: 0)
# ****: Differential inclusion (ns: 0)
# ****: Differential variational inequality (ns: 0)
# ****: Discrete time and continuous time (ns: 0)
# ****: Dissipation (ns: 0)
# ****: Dissipation factor (ns: 0)
# ****: Distribution function (physics) (ns: 0)
# ****: Dragon King Theory (ns: 0)
# ****: Dynamic aperture (accelerator physics) (ns: 0)
# ****: Dynamic equation (ns: 0)
# ****: Dynamical billiards (ns: 0)
# ****: Dynamical neuroscience (ns: 0)
# ****: Dynamical system (definition) (ns: 0)
# ****: Dynamical systems theory (ns: 0)
# ****: Entrainment (physics) (ns: 0)
# ****: Equichordal point problem (ns: 0)
# ****: Equidistributed sequence (ns: 0)
# ****: Equilibrium point (ns: 0)
# ****: System equivalence (ns: 0)
# ****: Euler's Disk (ns: 0)
# ****: Eulerian coherent structure (ns: 0)
# ****: Excitable medium (ns: 0)
# ****: Expansive homeomorphism (ns: 0)
# ****: Exponential dichotomy (ns: 0)
# ****: Exponential stability (ns: 0)
# ****: False nearest neighbor algorithm (ns: 0)
# ****: Fatou conjecture (ns: 0)
# ****: Feigenbaum constants (ns: 0)
# ****: Feigenbaum function (ns: 0)
# ****: Fermi–Pustyl'nikov model (ns: 0)
# ****: Fermi–Ulam model (ns: 0)
# ****: Floquet theory (ns: 0)
# ****: Flow (mathematics) (ns: 0)
# ****: Fractal analysis (ns: 0)
# ****: Fractal dimension (ns: 0)
# ****: Fractional-order system (ns: 0)
# ****: Free motion equation (ns: 0)
# ****: Fundamental ephemeris (ns: 0)
# ****: Gauss–Kuzmin–Wirsing operator (ns: 0)
# ****: Generalized coordinates (ns: 0)
# ****: Geometric mechanics (ns: 0)
# ****: Gradient-like dynamical systems (ns: 0)
# ****: Graph dynamical system (ns: 0)
# ****: Hamiltonian fluid mechanics (ns: 0)
# ****: Hamiltonian mechanics (ns: 0)
# ****: Heteroclinic cycle (ns: 0)
# ****: Heteroclinic network (ns: 0)
# ****: Heteroclinic orbit (ns: 0)
# ****: Hilbert's sixteenth problem (ns: 0)
# ****: Hitchin system (ns: 0)
# ****: Homoclinic connection (ns: 0)
# ****: Homoclinic orbit (ns: 0)
# ****: Horizon of predictability (ns: 0)
# ****: Hybrid system (ns: 0)
# ****: Hyperbolic set (ns: 0)
# ****: Hysteresivity (ns: 0)
# ****: System identification (ns: 0)
# ****: Inertial manifold (ns: 0)
# ****: Injection locking (ns: 0)
# ****: Integrable system (ns: 0)
# ****: Intermittency (ns: 0)
# ****: Interplanetary Transport Network (ns: 0)
# ****: Invariant manifold (ns: 0)
# ****: Invariant measure (ns: 0)
# ****: Irrational rotation (ns: 0)
# ****: Isochron (ns: 0)
# ****: Iterated filtering (ns: 0)
# ****: Iterated function (ns: 0)
# ****: Jet Propulsion Laboratory Development Ephemeris (ns: 0)
# ****: Kaplan–Yorke conjecture (ns: 0)
# ****: Koenigs function (ns: 0)
# ****: LaSalle's invariance principle (ns: 0)
# ****: Krylov–Bogoliubov averaging method (ns: 0)
# ****: Lagrange stability (ns: 0)
# ****: Lagrangian coherent structure (ns: 0)
# ****: Lagrangian mechanics (ns: 0)
# ****: Lagrangian system (ns: 0)
# ****: Langevin dynamics (ns: 0)
# ****: Lattès map (ns: 0)
# ****: Lefschetz zeta function (ns: 0)
# ****: Liénard equation (ns: 0)
# ****: Limit cycle (ns: 0)
# ****: Line field (ns: 0)
# ****: Linear difference equation (ns: 0)
# ****: Linear dynamical system (ns: 0)
# ****: Linear flow on the torus (ns: 0)
# ****: Linear system (ns: 0)
# ****: Linearization (ns: 0)
# ****: Time evolution (ns: 0)
# ****: Lyapunov exponent (ns: 0)
# ****: Lyapunov stability (ns: 0)
# ****: Lyapunov time (ns: 0)
# ****: Lyapunov vector (ns: 0)
# ****: Marginal stability (ns: 0)
# ****: Markov odometer (ns: 0)
# ****: Markov partition (ns: 0)
# ****: Master stability function (ns: 0)
# ****: Matrix difference equation (ns: 0)
# ****: Measure-preserving dynamical system (ns: 0)
# ****: Melnikov distance (ns: 0)
# ****: Metastability (ns: 0)
# ****: Method of averaging (ns: 0)
# ****: Michael Brin Prize in Dynamical Systems (ns: 0)
# ****: Micromagnetics (ns: 0)
# ****: Microscale and macroscale models (ns: 0)
# ****: Misiurewicz point (ns: 0)
# ****: Monogenic system (ns: 0)
# ****: Morse–Smale system (ns: 0)
# ****: Multibody simulation (ns: 0)
# ****: Multibody system (ns: 0)
# ****: Nekhoroshev estimates (ns: 0)
# ****: Non-autonomous system (mathematics) (ns: 0)
# ****: Non-smooth mechanics (ns: 0)
# ****: Nonlinear system (ns: 0)
# ****: Nonlinear system identification (ns: 0)
# ****: Normal form (dynamical systems) (ns: 0)
# ****: Normally hyperbolic invariant manifold (ns: 0)
# ****: Numerical continuation (ns: 0)
# ****: Numerical model of the Solar System (ns: 0)
# ****: Orbit (dynamics) (ns: 0)
# ****: Orbit modeling (ns: 0)
# ****: Orbit portrait (ns: 0)
# ****: Outer billiard (ns: 0)
# ****: Painlevé conjecture (ns: 0)
# ****: Parametric oscillator (ns: 0)
# ****: Parasitic oscillation (ns: 0)
# ****: Parry–Daniels map (ns: 0)
# ****: Parry–Sullivan invariant (ns: 0)
# ****: Pentagram map (ns: 0)
# ****: Perturbation (astronomy) (ns: 0)
# ****: Phase portrait (ns: 0)
# ****: Phase space (ns: 0)
# ****: Phase space method (ns: 0)
# ****: Poincaré map (ns: 0)
# ****: Poincaré plot (ns: 0)
# ****: Poincaré–Birkhoff theorem (ns: 0)
# ****: Pomeau–Manneville scenario (ns: 0)
# ****: Positive-definite function (ns: 0)
# ****: Predictive state representation (ns: 0)
# ****: Prefix order (ns: 0)
# ****: Presymplectic form (ns: 0)
# ****: Prime geodesic (ns: 0)
# ****: Projected dynamical system (ns: 0)
# ****: Pseudo-Anosov map (ns: 0)
# ****: Pugh's closing lemma (ns: 0)
# ****: Quasi-invariant measure (ns: 0)
# ****: Quasicircle (ns: 0)
# ****: Quasiperiodic motion (ns: 0)
# ****: Quasiperiodicity (ns: 0)
# ****: Rational dependence (ns: 0)
# ****: Rational difference equation (ns: 0)
# ****: Rayleigh–Ritz method (ns: 0)
# ****: Recurrence period density entropy (ns: 0)
# ****: Recurrence plot (ns: 0)
# ****: Recurrence quantification analysis (ns: 0)
# ****: Relativistic Lagrangian mechanics (ns: 0)
# ****: Rotation number (ns: 0)
# ****: Rotational–vibrational coupling (ns: 0)
# ****: Rulkov map (ns: 0)
# ****: Self-oscillation (ns: 0)
# ****: Separatrix (mathematics) (ns: 0)
# ****: Sequential dynamical system (ns: 0)
# ****: Shadowing lemma (ns: 0)
# ****: Shift space (ns: 0)
# ****: Slow manifold (ns: 0)
# ****: Stable manifold (ns: 0)
# ****: Stable manifold theorem (ns: 0)
# ****: State space (ns: 0)
# ****: Step response (ns: 0)
# ****: Stretching field (ns: 0)
# ****: Structural stability (ns: 0)
# ****: Superintegrable Hamiltonian system (ns: 0)
# ****: Superslow process (ns: 0)
# ****: Suspension (dynamical systems) (ns: 0)
# ****: Symbolic dynamics (ns: 0)
# ****: Thomas' cyclically symmetric attractor (ns: 0)
# ****: Time reversibility (ns: 0)
# ****: Time-scale calculus (ns: 0)
# ****: Transfer operator (ns: 0)
# ****: Translation surface (ns: 0)
# ****: Trapping region (ns: 0)
# ****: Unbounded system (ns: 0)
# ****: Universality (dynamical systems) (ns: 0)
# ****: Ushiki's theorem (ns: 0)
# ****: Vague torus (ns: 0)
# ****: Variable structure system (ns: 0)
# ****: Viability theory (ns: 0)
# ****: Virtual displacement (ns: 0)
# ****: Virtual work (ns: 0)
# ****: Volume entropy (ns: 0)
# ****: Wandering set (ns: 0)
# ****: Category:Theorems in dynamical systems (ns: 14)
# ****: Category:Dynamical systems theorists (ns: 14)
# ****: Category:Astronomical dynamical systems (ns: 14)
# ****: Category:Bifurcation theory (ns: 14)
# ****: Category:Chaos theory (ns: 14)
# ****: Category:Chaotic maps (ns: 14)
# ****: Category:Complex dynamics (ns: 14)
# ****: Category:Control engineering (ns: 14)
# ****: Category:Critical phenomena (ns: 14)
# ****: Category:Electrodynamics (ns: 14)
# ****: Category:Entropy (ns: 14)
# ****: Category:Entropy and information (ns: 14)
# ****: Category:Ergodic theory (ns: 14)
# ****: Category:Fixed points (mathematics) (ns: 14)
# ****: Category:Hamiltonian mechanics (ns: 14)
# ****: Category:Limit sets (ns: 14)
# ****: Category:Non-equilibrium thermodynamics (ns: 14)
# ****: Category:Nonlinear systems (ns: 14)
# ****: Category:Oscillation (ns: 14)
# ****: Category:Random dynamical systems (ns: 14)
# ****: Category:Self-organization (ns: 14)
# ****: Category:Stability theory (ns: 14)
# ****: Category:Symbolic dynamics (ns: 14)
# ****: Category:Thermodynamic systems (ns: 14)
# ****: Category:Thermodynamics (ns: 14)
# ****: Category:Topological dynamics (ns: 14)
# ****: Category:Vortices (ns: 14)
# ***: Category:Kinematics (ns: 14)
# ****: Kinematics (ns: 0)
# ****: Acceleration (ns: 0)
# ****: Block and tackle (ns: 0)
# ****: Bouncing ball (ns: 0)
# ****: Breit frame (ns: 0)
# ****: Cell Transmission Model (ns: 0)
# ****: Center-of-momentum frame (ns: 0)
# ****: Centripetal force (ns: 0)
# ****: Centrode (ns: 0)
# ****: Chasles' theorem (kinematics) (ns: 0)
# ****: Cylindrical joint (ns: 0)
# ****: De Sitter invariant special relativity (ns: 0)
# ****: Dual quaternion (ns: 0)
# ****: Fluid kinematics (ns: 0)
# ****: Kenneth H. Hunt (ns: 0)
# ****: Instant centre of rotation (ns: 0)
# ****: Instantaneous acceleration (ns: 0)
# ****: Kinematic pair (ns: 0)
# ****: Mechanical joint (ns: 0)
# ****: Pitch axis (kinematics) (ns: 0)
# ****: Prismatic joint (ns: 0)
# ****: Rational motion (ns: 0)
# ****: Revolute joint (ns: 0)
# ****: Rigid transformation (ns: 0)
# ****: Rotation (ns: 0)
# ****: Screw axis (ns: 0)
# ****: Screw joint (ns: 0)
# ****: Screw theory (ns: 0)
# ****: Shaft (mechanical engineering) (ns: 0)
# ****: Three-dimensional rotation operator (ns: 0)
# ****: Torricelli's equation (ns: 0)
# ****: Transverse mass (ns: 0)
# ****: Velocity (ns: 0)
# ****: Velocity-addition formula (ns: 0)
# ****: Virtual Reference Station (ns: 0)
# ****: Category:Acceleration (ns: 14)
# ****: Category:Mechanisms (engineering) (ns: 14)
# ****: Category:Kinematics (particle physics) (ns: 14)
# ****: Category:Robot kinematics (ns: 14)
# ***: Category:Mathematics of rigidity (ns: 14)
# ****: Alexandrov's uniqueness theorem (ns: 0)
# ****: Bricard octahedron (ns: 0)
# ****: Carpenter's rule problem (ns: 0)
# ****: Cauchy's theorem (geometry) (ns: 0)
# ****: Flexible polyhedron (ns: 0)
# ****: Laman graph (ns: 0)
# ****: Parallel redrawing (ns: 0)
# ****: Pseudotriangle (ns: 0)
# ****: Rigid graph (ns: 0)
# ****: Rigidity matroid (ns: 0)
# ****: Steffen's polyhedron (ns: 0)
# ****: Structural rigidity (ns: 0)
# ***: Category:Mechanical power control (ns: 14)
# ****: Active Body Control (ns: 0)
# ****: Active suspension (ns: 0)
# ****: Adjustable-speed drive (ns: 0)
# ****: Air suspension (ns: 0)
# ****: Anti-lock braking system (ns: 0)
# ****: Anti-roll bar (ns: 0)
# ****: Automatic transmission (ns: 0)
# ****: Bicycle chain (ns: 0)
# ****: Bicycle drivetrain systems (ns: 0)
# ****: Braking chopper (ns: 0)
# ****: Centrifugal governor (ns: 0)
# ****: Chain (ns: 0)
# ****: Chain conveyor (ns: 0)
# ****: Chain drive (ns: 0)
# ****: Dahlander pole changing motor (ns: 0)
# ****: DC injection braking (ns: 0)
# ****: Drive shaft (ns: 0)
# ****: Electronic brakeforce distribution (ns: 0)
# ****: Electronic differential (ns: 0)
# ****: Electronic stability control (ns: 0)
# ****: Escapement (ns: 0)
# ****: Governor (device) (ns: 0)
# ****: High-tensile chain (ns: 0)
# ****: Inverterization (ns: 0)
# ****: Kinetic Dynamic Suspension System (ns: 0)
# ****: Launch control (automotive) (ns: 0)
# ****: MagneRide (ns: 0)
# ****: Mitsubishi AWC (ns: 0)
# ****: O-ring chain (ns: 0)
# ****: Otto engine (ns: 0)
# ****: Power transmission (ns: 0)
# ****: Roller chain (ns: 0)
# ****: Self-lubricating chain (ns: 0)
# ****: Semi-automatic transmission (ns: 0)
# ****: Shock absorber (ns: 0)
# ****: Speed Dependent Damping Control (ns: 0)
# ****: Speed limiter (ns: 0)
# ****: Sprocket (ns: 0)
# ****: Steam turbine governing (ns: 0)
# ****: Torque amplifier (ns: 0)
# ****: Torque converter (ns: 0)
# ****: Toyota Active Control Suspension (ns: 0)
# ****: Toyota Electronic Modulated Suspension (ns: 0)
# ****: Traction control system (ns: 0)
# ****: Variable-frequency drive (ns: 0)
# ****: Variator (ns: 0)
# ****: Category:Chain drives (ns: 14)
# ****: Category:Escapements (ns: 14)
# ****: Category:Steam engine governors (ns: 14)
# ****: Category:Variators (ns: 14)
# ***: Category:Mechanical power transmission (ns: 14)
# ****: Power transmission (ns: 0)
# ****: Transmission (mechanics) (ns: 0)
# ****: Adjustable-speed drive (ns: 0)
# ****: Belt (mechanical) (ns: 0)
# ****: Braking chopper (ns: 0)
# ****: Chain (ns: 0)
# ****: Chain conveyor (ns: 0)
# ****: Chain drive (ns: 0)
# ****: Chebychev–Grübler–Kutzbach criterion (ns: 0)
# ****: Conveyor pulley (ns: 0)
# ****: Crawl ratio (ns: 0)
# ****: Hardy Spicer (ns: 0)
# ****: Dahlander pole changing motor (ns: 0)
# ****: DC injection braking (ns: 0)
# ****: Drive shaft (ns: 0)
# ****: Flat belt (ns: 0)
# ****: Flat chain (ns: 0)
# ****: Flexible shaft (ns: 0)
# ****: Fluid coupling (ns: 0)
# ****: Gearbox main drive retainer (ns: 0)
# ****: High-tensile chain (ns: 0)
# ****: Inverterization (ns: 0)
# ****: Jackshaft (locomotive) (ns: 0)
# ...
# ****: Category:Heating, ventilating, and air conditioning (ns: 14)
# ****: Category:Psychrometrics (ns: 14)
# ***: Category:Heat conduction (ns: 14)
# ****: Thermal grease (ns: 0)
# ****: Thermomass theory (ns: 0)
# ****: 3ω-method (ns: 0)
# ****: Annealed pyrolytic graphite (ns: 0)
# ****: Biot number (ns: 0)
# ****: Copper in heat exchangers (ns: 0)
# ****: Heat equation (ns: 0)
# ****: Heat flux measurements of thermal insulation (ns: 0)
# ****: Heat kernel (ns: 0)
# ****: Heat pipe (ns: 0)
# ****: Heat transfer coefficient (ns: 0)
# ****: Interfacial thermal resistance (ns: 0)
# ****: Internally grooved copper tube (ns: 0)
# ****: Laser flash analysis (ns: 0)
# ****: Loop heat pipe (ns: 0)
# ****: Lumped capacitance model (ns: 0)
# ****: Multi-layer insulation (ns: 0)
# ****: Newton's law of cooling (ns: 0)
# ****: Péclet number (ns: 0)
# ****: Relativistic heat conduction (ns: 0)
# ****: Searle's bar method (ns: 0)
# ****: Thermal conductance quantum (ns: 0)
# ****: Thermal conduction (ns: 0)
# ****: List of thermal conductivities (ns: 0)
# ****: Thermal conductivity (ns: 0)
# ****: Thermal contact conductance (ns: 0)
# ****: Thermal diffusivity (ns: 0)
# ****: Thermal effusivity (ns: 0)
# ****: Thermal resistance (ns: 0)
# ****: Category:High-temperature superconductors (ns: 14)
# ***: Category:Heat transfer (ns: 14)
# ****: Advection (ns: 0)
# ****: Aerodynamic heating (ns: 0)
# ****: Annealed pyrolytic graphite (ns: 0)
# ****: Annular fin (ns: 0)
# ****: Applied Thermal Engineering (ns: 0)
# ****: ASHRAE 55 (ns: 0)
# ****: Biothermia (ns: 0)
# ****: Black body (ns: 0)
# ****: Black-body radiation (ns: 0)
# ****: Boiling (ns: 0)
# ****: Boundary layer (ns: 0)
# ****: Building insulation (ns: 0)
# ****: Bulk temperature (ns: 0)
# ****: Burn (ns: 0)
# ****: Calorie (ns: 0)
# ****: Calorimetry (ns: 0)
# ****: Churchill–Bernstein equation (ns: 0)
# ****: Combined forced and natural convection (ns: 0)
# ****: Condenser (heat transfer) (ns: 0)
# ****: Thermal grease (ns: 0)
# ****: Thermomass theory (ns: 0)
# ****: Conjugate convective heat transfer (ns: 0)
# ****: Convection (ns: 0)
# ****: Convective heat transfer (ns: 0)
# ****: Cooling load (ns: 0)
# ****: Copper in heat exchangers (ns: 0)
# ****: Countercurrent exchange (ns: 0)
# ****: Crookes radiometer (ns: 0)
# ****: CuproBraze (ns: 0)
# ****: Decay heat (ns: 0)
# ****: Double glazing (ns: 0)
# ****: Draper point (ns: 0)
# ****: Droplet cluster (ns: 0)
# ****: Dropwise condensation (ns: 0)
# ****: Earth's internal heat budget (ns: 0)
# ****: Effect of radiation on perceived temperature (ns: 0)
# ****: Effectiveness (ns: 0)
# ****: Efficiency (ns: 0)
# ****: Egain forecasting (ns: 0)
# ****: Emissivity (ns: 0)
# ****: Equivalence of direct radiation (ns: 0)
# ****: Film temperature (ns: 0)
# ****: Fin (extended surface) (ns: 0)
# ****: Forced convection in porous media (ns: 0)
# ****: Gebhart factor (ns: 0)
# ****: Grashof number (ns: 0)
# ****: Green's function number (ns: 0)
# ****: Heat (ns: 0)
# ****: Heat bath (ns: 0)
# ****: Heat capacity rate (ns: 0)
# ****: Heat current (ns: 0)
# ****: Heat equation (ns: 0)
# ****: Heat exchanger (ns: 0)
# ****: Heat kernel signature (ns: 0)
# ****: Heat pipe (ns: 0)
# ****: Heat sink (ns: 0)
# ****: Heat spreader (ns: 0)
# ****: Heat transfer (ns: 0)
# ****: Heat transfer coefficient (ns: 0)
# ****: Heat transfer enhancement (ns: 0)
# ****: Heat transfer physics (ns: 0)
# ****: Heat transfer through fins (ns: 0)
# ****: Heat transfer vinyl (ns: 0)
# ****: Heat Transfer with Thermal Waves and Thermal Resonance (ns: 0)
# ****: Heisler chart (ns: 0)
# ****: Hydraulic diameter (ns: 0)
# ****: Hypothermia (ns: 0)
# ****: Infrared sensing in snakes (ns: 0)
# ****: Insulated glazing (ns: 0)
# ****: Intensity (heat transfer) (ns: 0)
# ****: Interfacial thermal resistance (ns: 0)
# ****: Internally grooved copper tube (ns: 0)
# ****: Isothermal microcalorimetry (ns: 0)
# ****: Isothermal technology (ns: 0)
# ****: Kernel function for solving integral equation of surface radiation exchanges (ns: 0)
# ****: Kilocalorie per mole (ns: 0)
# ****: Kirchhoff's law of thermal radiation (ns: 0)
# ****: Kleptothermy (ns: 0)
# ****: Laser flash analysis (ns: 0)
# ****: Leidenfrost effect (ns: 0)
# ****: Liquid droplet radiator (ns: 0)
# ****: Logarithmic mean temperature difference (ns: 0)
# ****: Mean radiant temperature (ns: 0)
# ****: Mesocosm (ns: 0)
# ****: Micro heat exchanger (ns: 0)
# ****: Moving heat source model for thin plates (ns: 0)
# ****: Multiphase heat transfer (ns: 0)
# ****: Nanofluid (ns: 0)
# ****: Nanofluids in solar collectors (ns: 0)
# ****: Natural convection (ns: 0)
# ****: Newton's law of cooling (ns: 0)
# ****: Non-ionizing radiation (ns: 0)
# ****: NTU method (ns: 0)
# ****: Nucleate boiling (ns: 0)
# ****: Nusselt number (ns: 0)
# ****: Passive cooling (ns: 0)
# ****: Perfect thermal contact (ns: 0)
# ****: Phonovoltaic (ns: 0)
# ****: Pipe insulation (ns: 0)
# ****: R-value (insulation) (ns: 0)
# ****: Radiant barrier (ns: 0)
# ****: Radiant cooling (ns: 0)
# ****: Radiation properties (ns: 0)
# ****: Radiosity (computer graphics) (ns: 0)
# ****: Recuperator (ns: 0)
# ****: Run-around coil (ns: 0)
# ****: Sorption calorimetry (ns: 0)
# ****: Spray foam (ns: 0)
# ****: Stefan–Boltzmann law (ns: 0)
# ****: Temperature (ns: 0)
# ****: Thermal break (ns: 0)
# ****: Thermal comfort (ns: 0)
# ****: Thermal conduction (ns: 0)
# ****: List of thermal conductivities (ns: 0)
# ****: Thermal conductivity (ns: 0)
# ****: Thermal contact (ns: 0)
# ****: Thermal contact conductance (ns: 0)
# ****: Thermal design power (ns: 0)
# ****: Thermal diffusivity (ns: 0)
# ****: Thermal energy storage (ns: 0)
# ****: Thermal equilibrium (ns: 0)
# ****: Thermal expansion (ns: 0)
# ****: Thermal history of the Earth (ns: 0)
# ****: Thermal inductance (ns: 0)
# ****: Thermal insulation (ns: 0)
# ****: Thermal interface material (ns: 0)
# ****: Thermal lag (ns: 0)
# ****: Thermal manikin (ns: 0)
# ****: Thermal mass (ns: 0)
# ****: Thermal radiation (ns: 0)
# ****: Thermal science (ns: 0)
# ****: Thermal shock (ns: 0)
# ****: Therminol (ns: 0)
# ****: Thermoacoustics (ns: 0)
# ****: Thermogenic plant (ns: 0)
# ****: Thermoregulation (ns: 0)
# ****: Thermoregulation in humans (ns: 0)
# ****: Turbulent Prandtl number (ns: 0)
# ****: View factor (ns: 0)
# ****: Volumetric heat capacity (ns: 0)
# ****: Waste heat (ns: 0)
# ****: Category:Convection (ns: 14)
# ****: Category:Coolants (ns: 14)
# ****: Category:Heat exchangers (ns: 14)
# ****: Category:Fictional characters with fire or heat abilities (ns: 14)
# ****: Category:Fire (ns: 14)
# ****: Category:Heat conduction (ns: 14)
# ****: Category:Heating, ventilating, and air conditioning (ns: 14)
# ****: Category:Insulators (ns: 14)
# ****: Category:Refractory materials (ns: 14)
# ****: Category:Thermal protection (ns: 14)
# ****: Category:Thermogenic plants (ns: 14)
# ****: Category:Thermoregulation (ns: 14)
# ****: Category:Torridness (ns: 14)
# ***: Category:History of thermodynamics (ns: 14)
# ****: History of thermodynamics (ns: 0)
# ****: Aeolipile (ns: 0)
# ****: Caloric theory (ns: 0)
# ****: Gas laws (ns: 0)
# ****: History of entropy (ns: 0)
# ****: History of heat (ns: 0)
# ****: Mechanical equivalent of heat (ns: 0)
# ****: History of perpetual motion machines (ns: 0)
# ****: Theory of heat (ns: 0)
# ****: Timeline of heat engine technology (ns: 0)
# ****: Timeline of thermodynamics (ns: 0)
# ****: Vis viva (ns: 0)
# ***: Category:Laws of thermodynamics (ns: 14)
# ****: Laws of thermodynamics (ns: 0)
# ****: Zeroth law of thermodynamics (ns: 0)
# ****: First law of thermodynamics (ns: 0)
# ****: Second law of thermodynamics (ns: 0)
# ****: Third law of thermodynamics (ns: 0)
# ****: Bergmann's rule (ns: 0)
# ****: Carnot's theorem (thermodynamics) (ns: 0)
# ****: Clausius theorem (ns: 0)
# ****: Conservation of energy (ns: 0)
# ****: Dulong–Petit law (ns: 0)
# ****: Equipartition theorem (ns: 0)
# ****: Ginsberg's theorem (ns: 0)
# ****: Kopp's law (ns: 0)
# ****: Neumann's law (ns: 0)
# ****: Onsager reciprocal relations (ns: 0)
# ****: Phase rule (ns: 0)
# ****: Stefan–Boltzmann law (ns: 0)
# ****: Theorem of corresponding states (ns: 0)
# ****: Time translation symmetry (ns: 0)
# ****: Triple product rule (ns: 0)
# ***: Category:Philosophy of thermal and statistical physics (ns: 14)
# ****: Philosophy of thermal and statistical physics (ns: 0)
# ****: Arrow of time (ns: 0)
# ****: Boltzmann brain (ns: 0)
# ****: Brownian ratchet (ns: 0)
# ****: Configuration entropy (ns: 0)
# ****: Entropy (ns: 0)
# ****: Entropy in thermodynamics and information theory (ns: 0)
# ****: Ergodic hypothesis (ns: 0)
# ****: H-theorem (ns: 0)
# ****: Kelvin–Planck statement (ns: 0)
# ****: Landauer's principle (ns: 0)
# ****: Loschmidt's paradox (ns: 0)
# ****: Maximum entropy thermodynamics (ns: 0)
# ****: Maxwell's demon (ns: 0)
# ****: Molecular chaos (ns: 0)
# ****: Quantum thermodynamics (ns: 0)
# ****: Second law of thermodynamics (ns: 0)
# ****: Statistical ensemble (mathematical physics) (ns: 0)
# ****: T-symmetry (ns: 0)
# ***: Category:Professorships in thermodynamics (ns: 14)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-120247d6c095> in <module>()
#      12 cat = wiki_wiki.page("Category:Physics")
#      13 print("Category members: Category:Physics")
# ---> 14 print_categorymembers(cat.categorymembers)
#
# <ipython-input-40-120247d6c095> in print_categorymembers(categorymembers, level, max_level)
#       7             print("%s: %s (ns: %d)" % ("*" * (level + 1), c.title, c.ns))
#       8             if c.ns == wikipediaapi.Namespace.CATEGORY and level <= max_level:
# ----> 9                 print_categorymembers(c.categorymembers, level + 1)
#      10
#      11
#
# <ipython-input-40-120247d6c095> in print_categorymembers(categorymembers, level, max_level)
#       7             print("%s: %s (ns: %d)" % ("*" * (level + 1), c.title, c.ns))
#       8             if c.ns == wikipediaapi.Namespace.CATEGORY and level <= max_level:
# ----> 9                 print_categorymembers(c.categorymembers, level + 1)
#      10
#      11
#
# <ipython-input-40-120247d6c095> in print_categorymembers(categorymembers, level, max_level)
#       7             print("%s: %s (ns: %d)" % ("*" * (level + 1), c.title, c.ns))
#       8             if c.ns == wikipediaapi.Namespace.CATEGORY and level <= max_level:
# ----> 9                 print_categorymembers(c.categorymembers, level + 1)
#      10
#      11
#
# ~/anaconda3/lib/python3.6/site-packages/wikipediaapi/wikipedia.py in categorymembers(self)
#     738     def categorymembers(self):
#     739         if not self._called['categorymembers']:
# --> 740             self._fetch('categorymembers')
#     741         return self._categorymembers
#     742
#
# ~/anaconda3/lib/python3.6/site-packages/wikipediaapi/wikipedia.py in _fetch(self, call)
#     742
#     743     def _fetch(self, call) -> 'WikipediaPage':
# --> 744         getattr(self.wiki, '_' + call)(self)
#     745         self._called[call] = True
#     746         return self
#
# ~/anaconda3/lib/python3.6/site-packages/wikipediaapi/wikipedia.py in _categorymembers(self, page)
#     323         raw = self._query(
#     324             page,
# --> 325             params
#     326         )
#     327         self._common_attributes(raw['query'], page)
#
# ~/anaconda3/lib/python3.6/site-packages/wikipediaapi/wikipedia.py in _query(self, page, params)
#     359             params=params,
#     360             headers=headers,
# --> 361             timeout=self.timeout,
#     362         )
#     363         return r.json()
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# ~/anaconda3/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# ~/anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     355             conn.request_chunked(method, url, **httplib_request_kw)
#     356         else:
# --> 357             conn.request(method, url, **httplib_request_kw)
#     358
#     359         # Reset the timeout for the recv() on the socket
#
# ~/anaconda3/lib/python3.6/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1237                 encode_chunked=False):
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#    1241     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~/anaconda3/lib/python3.6/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1283             # default charset of iso-8859-1.
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#    1287     def getresponse(self):
#
# ~/anaconda3/lib/python3.6/http/client.py in endheaders(self, message_body, encode_chunked)
#    1232         else:
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#    1236     def request(self, method, url, body=None, headers={}, *,
#
# ~/anaconda3/lib/python3.6/http/client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# ~/anaconda3/lib/python3.6/http/client.py in send(self, data)
#     962         if self.sock is None:
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#     966                 raise NotConnected()
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     164
#     165     def connect(self):
# --> 166         conn = self._new_conn()
#     167         self._prepare_conn(conn)
#     168
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     139         try:
#     140             conn = connection.create_connection(
# --> 141                 (self.host, self.port), self.timeout, **extra_kw)
#     142
#     143         except SocketTimeout as e:
#
# ~/anaconda3/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      71             if source_address:
#      72                 sock.bind(source_address)
# ---> 73             sock.connect(sa)
#      74             return sock
#      75
#
# KeyboardInterrupt:

# %% [markdown]
# ## Create test-set with documents from wikipedia

# %%
import json
import random
import wikipedia
filename = 'wikipedia_dump.json'
# downloading pages from the italian version of wikipedia
wikipedia.set_lang('it')

# create data structure to later dump as json file
docs = [] # this list will hold dictionaries in the form of {'title':__, 'abstract':__, 'flattened_entities':__}

# we'll fetch articles coming from this different fields
cities = ['Parigi', 'Londra', 'Roma', 'Berlino', 'Milano', 'Bologna']
fruits = ['Mela', 'Pera', 'Banana', 'Ciliegia', 'Lampone', 'Melone']
companies = ['Apple', 'Microsoft','Google', 'Facebook', 'Instagram', 'Amazon']
mixed_correalations = ['USA', 'Italia', 'Colosseo', 'New York', 'Casa Bianca', 'Quirinale', 'Pasta', 'Pizza', 'Hot dog']

# make a single list shuffling all elements
articles = cities + fruits + companies + mixed_correalations
print("Articles length: ",len(articles))
random.shuffle(articles)
print(articles)

# download each document in the list; document size will vary based on a random number of sentences returned
# by wikipedia APIs
for article in articles:
    sentences = random.randint(1, 10)
    text = ''
    try:
        text = wikipedia.summary(article, sentences = sentences)
    except wikipedia.exceptions.DisambiguationError as e:
        # if dimbaguations page shows up, take the first document
        text = wikipedia.summary(e.options[0], sentences = sentences)
    # create new dict with title and text of wikipedia page
    docs.append({'title': article, 'abstract': text, 'flattened_entities':''})
    
with open(filename, 'w') as outfile:
    json.dump(docs, outfile)
#print(docs)
# Out:
# Articles length:  27
# ['Microsoft', 'Lampone', 'Casa Bianca', 'Italia', 'Amazon', 'Berlino', 'Colosseo', 'New York', 'Instagram', 'Ciliegia', 'Mela', 'Parigi', 'Pasta', 'Londra', 'Bologna', 'Roma', 'Melone', 'Banana', 'Facebook', 'USA', 'Pizza', 'Milano', 'Quirinale', 'Pera', 'Google', 'Apple', 'Hot dog']

# %% [markdown]
# # 3 documents testing

# %%
# get 2 similar documents, and a random one
import json
import random
import wikipedia
filename = 'wikipedia_3docs_dump.json'
# downloading pages from the italian version of wikipedia
wikipedia.set_lang('it')

# create data structure to later dump as json file
docs = [] # this list will hold multiple similar docs threes
similar_docs = []# this list will hold dictionaries in the form of {'title':__, 'abstract':__, 'flattened_entities':__}

# we'll fetch articles coming from this different fields
cities = [('Parigi', 'Londra'), ('Roma', 'Berlino'), ('Milano', 'Bologna')]
fruits = [('Mela', 'Pera'), ('Banana', 'Ciliegia'), ('Lampone', 'Melone')]
companies = [('Apple','Microsoft'), ('Google', 'Amazon'), ('Instagram', 'Facebook')]
mixed_correlations = [('Fuoco', 'Fiamme'), ('Acqua', 'Ghiaccio'), ('Vento', 'Uragano'), 
                      ('Mark Zuckerberg', 'Facebook'), ('Marte (astronomia)', 'Venere (astronomia)'), ('NASA', 'Marte'),('Cometa', 'Stella'),
                      ('Juventus', 'Real Madrid'), ('iPad','iPhone'), ('Intel', 'AMD'), ('Cina', 'Pechino'),
                      ('Robot', 'Intelligenza Artificiale'), ('Intelligenza Artificiale', 'Machine Learning'), 
                      ('iPhone', 'Smartphone'), ('Amazon', 'e-commerce'), ('Android', 'Smartphone'),
                      ('Apple', 'Samsung'), ('Samsung', 'Corea del sud'), ('Astronomia', 'Pianeta'),
                      ('Sogno', 'Sognare'), ('Salto', 'Saltare'), ('Francia', 'Italia'), ('Corsa', 'Correre'),
                      ('Vita Nuova', 'Divina Commedia'), ('RHCP', 'Guns n roses'), ('Chino', 'Curvo'),
                      ('Armata', 'Esercito'), ('Armi', 'Pistola'), ('Benestante', 'Ricco'), 
                      ('Breve', 'Succinto'), ('Ginnasio','Palestra'), ('Questione', 'Domanda'),
                      ('Re','Regina'), ('Imperatore','Imperatrice'), ('Principe','Principessa'), ('Re','Principe'),
                      ('Regina','Principessa'), ('Valvassore','Valvassino'), ('Guelfi','Ghibellini'), 
                      ('Francesi','Francia'), ('Italiani','Italia'), ('Cadere','Cascare'), ('Molto', 'Assai'),
                      ('Uomo','Donna'), ('Figlio','Padre'), ('Bambino','Bambina'), ('Figlio','Bambino'), 
                      ('Cucciolo','Bambino'), ('Infante', 'Figlio'), ('Madre', 'Figlia'), ('Fratello', 'Sorella'),
                      ('Zio', 'Zia'), ('Padre', 'Nonno'), ('Madre', 'Nonna'), ('Nonno', 'Nipote')
                     ]
animals = [('Chiocciola','Lumaca'), ('Cane','Gatto'), ('Cane','Lupo'), ('Tigre','Pantera'), ('Pantera','Puma'),
          ('Ghepardo', 'Tigre'), ('Cavallo', 'Pony'), ('Mucca', 'Toro')
          ]

# make a single list shuffling all elements
articles = cities + fruits + companies + mixed_correlations + animals
print("Articles length: ",len(articles))
random.shuffle(articles)
print(articles)

# download each document in the list; document size will vary based on a random number of sentences returned
# by wikipedia APIs
for (art1, art2) in articles:
    sentences = random.randint(3, 8)
    similar_docs = []
    text0 = ''
    text1 = ''
    text2 = ''
    page_random = ''
    # get the summary of the two 'linked' documents
    try:
        text0 = wikipedia.summary(art1, sentences = sentences)
    except wikipedia.exceptions.DisambiguationError as e:
        # if dimbaguations page shows up, take the first document
        print(e.options[0])
        text0 = wikipedia.summary(e.options[0], sentences = sentences)
        
    sentences = random.randint(3, 8)
    try:
        text1 = wikipedia.summary(art2, sentences = sentences)
    except wikipedia.exceptions.DisambiguationError as e:
        # if dimbaguations page shows up, take the first document
        print(e.options[0])
        text1 = wikipedia.summary(e.options[0], sentences = sentences)
        
    # get a random article
    try:
        page_random = wikipedia.random(pages = 1)
        sentences = random.randint(3, 8)
        text2 = wikipedia.summary(page_random, sentences = sentences)
    except wikipedia.exceptions.DisambiguationError as e:
        # if dimbaguations page shows up, take the first document
        print(e.options[0])
        text2 = wikipedia.summary(e.options[0], sentences = sentences)
            
    # create new dict with title and text of the 3 wikipedia pages    
    similar_docs.append({'title': art1, 'abstract': text0, 'flattened_entities':''})
    similar_docs.append({'title': art2, 'abstract': text1, 'flattened_entities':''})
    similar_docs.append({'title': page_random, 'abstract': text2, 'flattened_entities':''})
    
    docs.append(similar_docs)
with open(filename, 'w') as outfile:
    json.dump(docs, outfile)
print("File saved")
#print(docs)
# Out:
# Articles length:  27
# [('Cometa', 'Stella'), ('Lampone', 'Melone'), ('Mark Zuckerberg', 'Facebook'), ('Android', 'Smartphone'), ('Milano', 'Bologna'), ('Parigi', 'Londra'), ('Amazon', 'e-commerce'), ('Roma', 'Berlino'), ('Vento', 'Uragano'), ('Banana', 'Ciliegia'), ('Data Science', 'Machine Learning'), ('iPhone', 'Smartphone'), ('Google', 'Amazon'), ('Acqua', 'Ghiaccio'), ('Cina', 'Pechino'), ('Apple', 'Samsung'), ('Fuoco', 'Fiamme'), ('Marte (Pianeta)', 'Venere'), ('Apple', 'Microsoft'), ('Samsung', 'Corea del sud'), ('NASA', 'Marte'), ('Mela', 'Pera'), ('iPad', 'iPhone'), ('Juventus', 'Real Madrid'), ('Instagram', 'Facebook'), ('Intel', 'CPU'), ('Robot', 'Intelligenza Artificiale')]
# /home/nick/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/nick/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# codice aeroportuale IATA
# Arnolfo III di Fiandra
# Intelligent network
# File saved
