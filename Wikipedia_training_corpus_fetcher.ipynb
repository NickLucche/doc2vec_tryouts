# %% [markdown]
# # Get training corpus from Wikipedia
# first approach will be downloading a lot of documents summaries,
# which are the first rows of a Wikipedia page.
# Without any parallelization it should take more than a hour

# %%
import wikipedia
import json
import random
import time
import datetime

# the idea is to retrieve a lot of documents from wikipedia, in order to train a Doc2Vec model 
# the documents will then be dumped to disk in json format
filename = 'wikipedia_trainig_corpus.json'
training_corpus_size = 10000
docs_to_avoid = []
wikipedia.set_lang('it')
wikipedia.set_rate_limiting(True) # w/ default timeout value
docs = []
batch_size = 50
for i in range(training_corpus_size//batch_size):
    # get a random page title
    titles = wikipedia.random(pages=batch_size) # Consider making multiple requests!
    for title in titles:
        if title in docs_to_avoid:
            continue # these docs will only result in Exceptions
        summary = ''
        try:
            summary = wikipedia.summary(title)
        except wikipedia.exceptions.DisambiguationError as e:
            try:
                # disambiguation page showed up, fetch a random one (among the first articles)
                index = random.randint(0, (len(e.options)-1)//2)
                summary = wikipedia.summary(e.options[index])
            except wikipedia.exceptions.DisambiguationError as e:
                # sometimes e.options doesn't really help..
                # we'll rule out this word
                docs_to_avoid.append(title)
                print("Bad exception occurred")
                continue
            except:
                # another weird error from wikipedia
                print("Weird error, like page id not found")
                continue
        except wikipedia.exceptions.WikipediaException as we:
            # something wrong (probably can't connect)
            print("Something went wrong..", we)
            continue
        dictionary = {'title':title, 'abstract': summary}
        docs.append(dictionary)
    print("Still working! {0} pages collected.{1}".format((i+1)*batch_size, datetime.datetime.now().time()))
    if (i%(10000//batch_size))==0:
        print("10000 pages milestone.")
        print("Docs to avoid length: ", len(docs_to_avoid))
print("Pages retrieved!")
with open(filename, 'w') as out:
    json.dump(docs, out, indent=4, ensure_ascii=False)
print('File saved!')
print(len(docs))
# Out:
# /home/nick/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/nick/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# Bad exception occurred
# Still working! 50 pages collected.12:32:46.095210
# 10000 pages milestone.
# Docs to avoid length:  1
# Bad exception occurred
# Bad exception occurred
# Bad exception occurred
# Still working! 100 pages collected.12:34:05.536030
# Bad exception occurred
# Bad exception occurred
# Still working! 150 pages collected.12:35:19.570246
# Still working! 200 pages collected.12:36:34.662407
# Still working! 250 pages collected.12:37:47.394356
# Still working! 300 pages collected.12:39:03.227225
# Still working! 350 pages collected.12:40:21.263844
# Still working! 400 pages collected.12:41:37.890200
# Bad exception occurred
# Still working! 450 pages collected.12:42:54.150614
# Bad exception occurred
# Still working! 500 pages collected.12:44:11.835396
# Still working! 550 pages collected.12:45:26.234718
# Bad exception occurred
# Still working! 600 pages collected.12:46:49.941499
# Bad exception occurred
# Still working! 650 pages collected.12:48:08.007686
# Bad exception occurred
# Still working! 700 pages collected.12:49:24.090521
# Bad exception occurred
# Still working! 750 pages collected.12:50:41.421612
# Bad exception occurred
# Still working! 800 pages collected.12:52:01.811155
# Bad exception occurred
# Still working! 850 pages collected.12:53:21.889667
# Bad exception occurred
# Bad exception occurred
# Still working! 900 pages collected.12:54:41.469936
# Bad exception occurred
# Bad exception occurred
# Still working! 950 pages collected.12:55:57.664017
# Still working! 1000 pages collected.12:57:11.108497
# Bad exception occurred
# Still working! 1050 pages collected.12:58:28.986859
# Still working! 1100 pages collected.12:59:47.531430
# Bad exception occurred
# Still working! 1150 pages collected.13:01:07.523851
# Bad exception occurred
# Bad exception occurred
# Bad exception occurred
# Bad exception occurred
# Bad exception occurred
# Still working! 8250 pages collected.16:03:21.790253
# Something went wrong.. Page id "us open 1981 singolare femminile" does not match any pages. Try another id!
# Still working! 8300 pages collected.16:04:37.154924
# Still working! 8350 pages collected.16:05:51.480545
# Bad exception occurred
# Still working! 8400 pages collected.16:07:13.647145
# Bad exception occurred
# Something went wrong.. Page id "coppa di turchia 2010 2011 pallavolo femminile" does not match any pages. Try another id!
# Still working! 8450 pages collected.16:08:30.091146
# Bad exception occurred
# Something went wrong.. Page id "división de honor 2006 2007 calcio a 5" does not match any pages. Try another id!
# Still working! 8500 pages collected.16:09:47.810242
# Still working! 8550 pages collected.16:11:04.379011
# Bad exception occurred
# Bad exception occurred
# Still working! 8600 pages collected.16:12:20.360667
# Bad exception occurred
# Bad exception occurred
# Still working! 8650 pages collected.16:13:37.098310
# Still working! 8700 pages collected.16:14:50.334511
# Bad exception occurred
# Bad exception occurred
# Still working! 8750 pages collected.16:16:11.475769
# Still working! 8800 pages collected.16:17:28.058380
# Bad exception occurred
# Still working! 8850 pages collected.16:18:43.920823
# Still working! 8900 pages collected.16:19:58.413593
# Bad exception occurred
# Still working! 8950 pages collected.16:21:16.475254
# Still working! 9000 pages collected.16:22:31.536147
# Something went wrong.. Page id "fiba european champions cup 1986 1987" does not match any pages. Try another id!
# Bad exception occurred
# Still working! 9050 pages collected.16:23:45.318674
# Still working! 9100 pages collected.16:25:00.435437
# Bad exception occurred
# Something went wrong.. Page id "nati" does not match any pages. Try another id!
# Still working! 9150 pages collected.16:26:15.240174
# Bad exception occurred
# Still working! 9200 pages collected.16:27:32.423719
# Bad exception occurred
# Still working! 9250 pages collected.16:28:47.688346
# Bad exception occurred
# Still working! 9300 pages collected.16:30:02.538966
# Bad exception occurred
# Bad exception occurred
# Bad exception occurred
# Still working! 9350 pages collected.16:31:20.966837
# Bad exception occurred
# Still working! 9400 pages collected.16:32:36.220437
# Still working! 9450 pages collected.16:33:54.819273
# Still working! 9500 pages collected.16:35:13.020767
# Still working! 9550 pages collected.16:36:31.338473
# Bad exception occurred
# Still working! 9600 pages collected.16:37:49.950002
# Bad exception occurred
# Bad exception occurred
# Still working! 9650 pages collected.16:39:07.912920
# Bad exception occurred
# Still working! 9700 pages collected.16:40:25.778829
# Bad exception occurred
# Still working! 9750 pages collected.16:41:44.009226
# Still working! 9800 pages collected.16:43:02.452729
# Bad exception occurred
# Still working! 9850 pages collected.16:44:17.680967
# Bad exception occurred
# Bad exception occurred
# Still working! 9900 pages collected.16:45:35.796418
# Still working! 9950 pages collected.16:46:55.655692
# Bad exception occurred
# Bad exception occurred
# Still working! 10000 pages collected.16:48:17.822038
# Pages retrieved!
# File saved!
# 9781

# %%
wikipedia.set_lang('it')
import random
try:
        summary = wikipedia.summary('Corsa')
except wikipedia.exceptions.DisambiguationError as e:
        # disambiguation page showed up, fetch a random one (among the first articles)
        print(e)
        index = random.randint(0, (len(e.options)-1)//2)
        summary = wikipedia.summary(e.options[5])
print(summary)
# Out:
# /home/nick/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/nick/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# "Corsa" may refer to:
# Corsa
# Corsa
# Corsa
# Corsa
# Corsa
# Wikizionario
#
# Il Wikizionario è un progetto collaborativo, multilingue e gratuito, tramite la Rete, supportato dalla Wikimedia Foundation, per produrre un dizionario online libero e multilingue, con significati, etimologie e pronunce, attraverso l'uso di una piattaforma wiki in maniera del tutto simile a Wikipedia di cui è un compagno lessicale.
